# %%
# check new data and load

# %%
from IPython.display import display
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import shutil
import datetime

import os
import sys
sys.path.append(os.path.dirname(os.path.abspath(''))+'/wfdb-python')
import wfdb
from wfdb import processing

# %%
PATH_MIMIC2 = '/home/nsc/seers/physionet/database/mimic2db'
PATH_CHALLENGE2015 = '/home/nsc/seers/physionet/database/challenge-2015/training'
PATH_MC100 = '/home/nsc/seers/cardio/database/mc100/'
PATH_TARGET = PATH_MC100
#PATH_DATASET = '/home/nsc/seers/dataset'
PATH_DATASET = '/home/nsc/seers/temp'
MODEL_NAME = 'life-threatening_arrhythmias'
FILE_RECORD_LIST = 'RECORDS'
TARGET_FS = 250
TARGET_TIME = 10 # 10 second

ARRHYTHMIAS_NAME_1 = ['Asystole', 
                      'Bradycardia', 
                      'Tachycardia', 
                      'Ventricular_Tachycardia', 
                      'Ventricular_Flutter_Fib'
                     ]
ARRHYTHMIAS_NAME_2 = ['ASYSTOLE', 
                      'BRADY', 
                      'TACHY', 
                      'V-TACH', 
                      'V-FIB/TACH'
                     ]
ARRHYTHMIAS_NAME_2TO1 = dict(zip(ARRHYTHMIAS_NAME_2, ARRHYTHMIAS_NAME_1))
ARRHYTHMIAS_NAME_1TO2 = dict(zip(ARRHYTHMIAS_NAME_1, ARRHYTHMIAS_NAME_2))
list_record = []
dic_list_true = {}
dic_list_false = {}
for arrhythmias in ARRHYTHMIAS_NAME_1:
    dic_list_true[arrhythmias] = []
    dic_list_false[arrhythmias] = []


dic_dtype = {'measurementId': 'i',
            'measurementCode': 'S',
            'measurementStatus': 'i',
            'registerUserId': 'i',
            'organizationId': 'i',
            'patientCode': 'S',
            'startDateTime': 'S',
            'endDateTime': 'S',
            'downloadDateTime': 'S',
            'ECGUrl': 'S',
            'fileSize': 'i',
            'sampling': 'i',
            'gain': 'f',
            'endian': 'i',
            'analysisUrl': 'S',
            'storePath': 'S',
            'pridictStatus': 'S',
            'makeDatasetStatus': 'S'}

dic_schema = {'measurementId':np.array([], dtype='i'),
            'measurementCode': np.array([], dtype='S'),
            'measurementStatus': np.array([], dtype='i'),
            'registerUserId': np.array([], dtype='i'),
            'organizationId': np.array([], dtype='i'),
            'patientCode': np.array([], dtype='S'),
            'startDateTime': np.array([], dtype='S'),
            'endDateTime': np.array([], dtype='S'),
            'downloadDateTime': np.array([], dtype='S'),
            'ECGUrl': np.array([], dtype='S'),
            'fileSize': np.array([], dtype='i'),
            'sampling': np.array([], dtype='i'),
            'gain': np.array([], dtype='f'),
            'endian': np.array([], dtype='i'),
            'analysisUrl':np.array([], dtype='S'),
            'storePath': np.array([], dtype='S'),
            'pridictStatus': np.array([], dtype='S'),
            'makeDatasetStatus': np.array([], dtype='S')}

MC100_CSV = 'seers_cardio_database_mc100.csv'
MC100_CSV = os.path.join(PATH_MC100, MC100_CSV)

if os.path.isfile(MC100_CSV):
    df_mc100 = pd.read_csv(MC100_CSV, sep=',', dtype=dic_dtype)
else:
    df_mc100 = pd.DataFrame(dic_schema)

print (df_mc100.dtypes)   
df_mc100
# Out:
# measurementId          int32
# measurementCode       object
# measurementStatus      int32
# registerUserId         int32
# organizationId         int32
# patientCode           object
# startDateTime         object
# endDateTime           object
# downloadDateTime      object
# ECGUrl                object
# fileSize               int32
# sampling               int32
# gain                 float32
# endian                 int32
# analysisUrl           object
# storePath             object
# pridictStatus         object
# makeDatasetStatus     object
# dtype: object
#    measurementId     measurementCode  measurementStatus  registerUserId  \
# 0            349  SN191018MC100_P007                  7              21
# 1            346  SN191018MC100_P006                  7              21
# 2            337  SN191016MC100_P005                  7              21
# 3            336  SN191016MC100_P004                  7              21
# 4            335  SN191016MC100_P003                  7              21
# 5            329  SN191016MC100_P002                  7              21
# 6            327  SN191016MC100_P001                  7              21
# 7            110              NSTest                  7              21
#
#    organizationId  patientCode        startDateTime          endDateTime  \
# 0               8          NaN  2019-10-18 13:30:40  2019-10-18 14:01:39
# 1               8          NaN  2019-10-18 12:57:36  2019-10-18 13:28:11
# 2               8          NaN  2019-10-16 16:24:04  2019-10-16 16:55:15
# 3               8          NaN  2019-10-16 15:47:10  2019-10-16 16:20:38
# 4               8          NaN  2019-10-16 15:01:22  2019-10-16 15:32:07
# 5               8          NaN  2019-10-16 13:55:39  2019-10-16 14:26:26
# 6               8          NaN  2019-10-16 12:48:53  2019-10-16 13:33:15
# 7               8  SEERSWESLEY  2019-08-30 14:25:05  2019-08-30 18:44:58
#
#       downloadDateTime                                             ECGUrl  \
# 0  2019-10-21 22:12:49  http://13.125.86.65:8080/mobiCARE/cardio/Measu...
# 1  2019-10-21 22:12:50  http://13.125.86.65:8080/mobiCARE/cardio/Measu...
# 2  2019-10-21 22:12:52  http://13.125.86.65:8080/mobiCARE/cardio/Measu...
# 3  2019-10-21 22:12:53  http://13.125.86.65:8080/mobiCARE/cardio/Measu...
# 4  2019-10-21 22:12:55  http://13.125.86.65:8080/mobiCARE/cardio/Measu...
# 5  2019-10-21 22:12:56  http://13.125.86.65:8080/mobiCARE/cardio/Measu...
# 6  2019-10-21 22:12:58  http://13.125.86.65:8080/mobiCARE/cardio/Measu...
# 7  2019-10-21 22:13:09  http://13.125.86.65:8080/mobiCARE/cardio/Measu...
#
#    fileSize  sampling   gain  endian  \
# 0    952064       256  100.0       1
# 1    939520       256  100.0       1
# 2    958464       256  100.0       1
# 3   1028608       256  100.0       1
# 4    944640       256  100.0       1
# 5    946176       256  100.0       1
# 6   1362944       256  100.0       1
# 7   7984384       256  100.0       1
#
#                                          analysisUrl  \
# 0  http://13.125.86.65:8080/mobiCARE/cardio/Analy...
# 1  http://13.125.86.65:8080/mobiCARE/cardio/Analy...
# 2  http://13.125.86.65:8080/mobiCARE/cardio/Analy...
# 3  http://13.125.86.65:8080/mobiCARE/cardio/Analy...
# 4  http://13.125.86.65:8080/mobiCARE/cardio/Analy...
# 5  http://13.125.86.65:8080/mobiCARE/cardio/Analy...
# 6  http://13.125.86.65:8080/mobiCARE/cardio/Analy...
# 7  http://13.125.86.65:8080/mobiCARE/cardio/Analy...
#
#                                            storePath pridictStatus  \
# 0  /home/nsc/seers/cardio/database/mc100/SN191018...         False
# 1  /home/nsc/seers/cardio/database/mc100/SN191018...         False
# 2  /home/nsc/seers/cardio/database/mc100/SN191016...         False
# 3  /home/nsc/seers/cardio/database/mc100/SN191016...         False
# 4  /home/nsc/seers/cardio/database/mc100/SN191016...         False
# 5  /home/nsc/seers/cardio/database/mc100/SN191016...         False
# 6  /home/nsc/seers/cardio/database/mc100/SN191016...         False
# 7       /home/nsc/seers/cardio/database/mc100/NSTest         False
#
#   makeDatasetStatus
# 0              True
# 1              True
# 2              True
# 3              True
# 4              True
# 5              True
# 6              True
# 7              True

# %%
# !pwd
# Out:
# /home/nsc/seers/seers_cai_mb/notebook

# %%
def arrhythmias_name(comment):
    for name in ARRHYTHMIAS_NAME_2:
        if name in comment:
            return ARRHYTHMIAS_NAME_2TO1[name]
    return None

# %%
dir_list = os.listdir(os.path.join(PATH_TARGET))
list_record = []
for directory in dir_list:
    if os.path.isdir(os.path.join(PATH_DATASET, directory)) is False:
        continue
    if os.listdir(os.path.join(PATH_TARGET, directory)):
        list_record.append(directory)
print(list_record)
# Out:
# ['SN191016MC100_P004', 'NSTest', 'SN191018MC100_P006', 'SN191018MC100_P007', 'SN191016MC100_P001', 'SN191016MC100_P005', 'SN191016MC100_P002', 'SN191016MC100_P003']

# %% [raw]
# #list_record = ['NSTest']
#
# for record in list_record:
#     file_record = os.path.join(PATH_TARGET, record, record)
#     annotation = wfdb.rdann(file_record, 'alM')
#     wfdb.plot_wfdb(annotation=annotation, time_units='seconds')
#     display(annotation.__dict__)

# %%
import numpy as np
from scipy import signal

# %%
def resample_sig(x, fs, fs_target):
    """
    Resample a signal to a different frequency.

    Parameters
    ----------
    x : numpy array
        Array containing the signal
    fs : int, or float
        The original sampling frequency
    fs_target : int, or float
        The target frequency

    Returns
    -------
    resampled_x : numpy array
        Array of the resampled signal values
    resampled_t : numpy array
        Array of the resampled signal locations

    """
    t = np.arange(x.shape[0]).astype('float64')

    if fs == fs_target:
        return x, t

    new_length = int(x.shape[0]*fs_target/fs)
    resampled_x, resampled_t = signal.resample(x, num=new_length, t=t)

    # assert resampled_x.shape == resampled_t.shape and resampled_x.shape[0] == new_length
    # assert np.all(np.diff(resampled_t) > 0)

    return resampled_x, resampled_t

# %%
def replace_nan(x):
    print(np.argwhere(np.isnan(x)))
    nan_list = np.argwhere(np.isnan(x))
    for nan_p in nan_list:
        if nan_p[0] == 0:
            if np.isnan(x[nan_p[0]+1][nan_p[1]]):
                print('start nan')
                x[nan_p[0]+1][nan_p[1]] = 0.
            x[nan_p[0]][nan_p[1]] = x[nan_p[0]+1][nan_p[1]]
        else:
            x[nan_p[0]][nan_p[1]] = x[nan_p[0]-1][nan_p[1]]
    print(np.argwhere(np.isnan(x)))

# %%
print('target record number : ', len(list_record))
for num, record in enumerate(list_record):
    #if num < 7 : continue
    file_record = os.path.join(PATH_TARGET, record, record)
    annotation = wfdb.rdann(file_record, 'alM')
    print ('%d. read record : %s - sample : %d' % (num+1, file_record, len(annotation.sample)))
    # wfdb.plot_wfdb(annotation=annotation, time_units='seconds')

    for idx, sample in enumerate(annotation.sample):
        #if idx < 12 : continue
        sample_name = "%s-a%d" % (record, idx+1)
        str_title = ("%s %s %s(%d) %s" % 
                      (sample_name, 
                       "True" if annotation.chan[idx] == 1 else "False",
                       str(datetime.timedelta(seconds=sample/annotation.fs)), 
                       sample, annotation.aux_note[idx]))
        print('  %d-%d. %s' % (num+1, idx+1, str_title))
        
        record_10s_sampfrom = sample - annotation.fs * TARGET_TIME
        if record_10s_sampfrom < 0:
            record_10s_sampfrom = 0
        record_10s_sampto = sample
        if record_10s_sampto < annotation.fs * TARGET_TIME:
            record_10s_sampto = annotation.fs * TARGET_TIME
            
        record_10s = wfdb.rdrecord(file_record, 
                                   sampfrom = record_10s_sampfrom,
                                   sampto = record_10s_sampto)
        #wfdb.plot_wfdb(record=record_10s, title=str_title, time_units='seconds')
        
        try:
            record_10s_ii = wfdb.rdrecord(file_record, 
                                       channels = [record_10s.sig_name.index('II')], 
                                       sampfrom = record_10s_sampfrom,
                                       sampto = record_10s_sampto)
        except Exception as ex:
            print ("rdrecord exception (not exist II) : ", ex)
            continue
        
        comments_arrhythmias = arrhythmias_name(annotation.aux_note[idx])
        comments_truefalse = True if annotation.chan[idx] == 1 else False
        if comments_arrhythmias is None:
            print ('  ** annotation error : ', annotation.aux_note[idx], comments_arrhythmias)
            # raise IndexError('Not define arrhythmias')
            continue
            
        if record_10s_ii.fmt is None or record_10s_ii.adc_gain is None:
            print ('  ** none data ')
            continue
        if record_10s_ii.fmt[0] is None or record_10s_ii.adc_gain[0] is None:
            print ('  ** none data ')
            continue
        if np.all(np.isnan(record_10s_ii.p_signal)):
            print ('  ** all data is nan')
            continue
        if np.all(record_10s_ii.p_signal == 0.):
            print ('  ** all data is 0.')
            continue
            
        #wfdb.plot_wfdb(record=record_10s_ii, title=str_title, time_units='seconds')
        #display(record_10s_ii.__dict__)     

        sample_path = os.path.join(PATH_DATASET, 
                                   MODEL_NAME, 
                                   "true" if annotation.chan[idx] == 1 else "false", 
                                   comments_arrhythmias,
                                   sample_name)
        if os.path.isdir(sample_path) is not True:
            try:
                os.makedirs(sample_path, exist_ok=True)
            except OSError as ex:
                raise
        
        d = record_10s_ii.base_date
        t = record_10s_ii.base_time
        dt = datetime.datetime.combine(d, t)
        dt2 = dt + datetime.timedelta(seconds=record_10s_sampfrom/annotation.fs)
        
        if np.isnan(record_10s_ii.p_signal).any():
            replace_nan(record_10s_ii.p_signal)
        
        # print(record_10s_ii.p_signal.shape)
        # resampled_x, resampled_t = processing.resample_sig(record_10s_ii.p_signal, record_10s_ii.fs, TARGET_FS)
        resampled_x, resampled_t = resample_sig(record_10s_ii.p_signal, record_10s_ii.fs, TARGET_FS)
        
        if np.all(np.isnan(resampled_x)):
            print ('  ** all resampled data is nan')
            wfdb.plot_wfdb(record=record_10s_ii, title=str_title, time_units='seconds')
            display(record_10s_ii.__dict__)     
            raise
            continue
            
        record_10s_ii.fs = TARGET_FS
        record_10s_ii.sig_len = resampled_x.shape[0]
        record_10s_ii.p_signal = resampled_x       
        record_10s_ii.record_name = sample_name
        record_10s_ii.base_date = dt2.date()
        record_10s_ii.base_time = dt2.time()
        record_10s_ii.base_datetime = dt2
        record_10s_ii.fmt = ['16']        
        record_10s_ii.comments = [comments_arrhythmias,
                                    "True alarm" if annotation.chan[idx] == 1 else "False alarm", 
                                    annotation.aux_note[idx]
                                   ]
        str_title = ("load %s %s %s" % 
                      (record_10s_ii.record_name,
                       record_10s_ii.comments[0],
                       "True" if annotation.chan[idx] == 1 else "False")
                    )
        try:
            print('  %d-%d. write %s' % (num+1, idx+1, sample_path))
            # display(record_10s_ii.__dict__)
            wfdb.wrsamp(record_name = record_10s_ii.record_name, 
                        fs = record_10s_ii.fs, 
                        units = record_10s_ii.units,
                        sig_name = record_10s_ii.sig_name,
                        p_signal = record_10s_ii.p_signal,
                        fmt = record_10s_ii.fmt,
                        adc_gain = record_10s_ii.adc_gain,
                        baseline = record_10s_ii.baseline,
                        base_time = record_10s_ii.base_time,
                        base_date = record_10s_ii.base_date,
                        comments = record_10s_ii.comments,
                        write_dir = sample_path
                       )
            np.savetxt(os.path.join(sample_path, sample_name+'.csv'),
                          record_10s_ii.p_signal, fmt='%.5f', delimiter=",")
            print('  %d-%d. %s' % (num+1, idx+1, str_title))
            record_sample = wfdb.rdrecord(os.path.join(sample_path, sample_name))
            # wfdb.plot_wfdb(record=record_sample, time_units='seconds', title=str_title) 
            # display(record_sample.__dict__)
            plt_fig = wfdb.figure_wfdb(record=record_sample, time_units='seconds', 
                                        title=str_title, figsize=(10, 4), return_fig=True)
            plt_fig.savefig(os.path.join(sample_path, sample_name), dpi=100)    
        
            if annotation.chan[idx] == 1:
                dic_list_true[comments_arrhythmias].append(record_10s_ii.record_name)
            else:
                dic_list_false[comments_arrhythmias].append(record_10s_ii.record_name)
    
    
        except Exception as ex:
            print ("exception : ", ex)
            raise Exception

    df_mc100_measurement_index = df_mc100.loc[df_mc100['measurementCode'] == record].index
    print ('df_mc100 measurement index : ', df_mc100_measurement_index)
    
    if df_mc100_measurement_index.size is 0:
        continue

    print ('df_mc100 make dataset status : ', df_mc100['makeDatasetStatus'][df_mc100_measurement_index[0]])
    if df_mc100['makeDatasetStatus'][df_mc100_measurement_index[0]] == True:
        print ('skip : aleady set True makeDatasetStatus')
        continue
    print ('Set True makeDatasetStatus')
    df_mc100['makeDatasetStatus'][df_mc100_measurement_index[0]] = True


if len(df_mc100) is not 0:
    df_mc100.to_csv(MC100_CSV, index = False, mode='w')

print('')
count_true = 0
count_false = 0
for key in ARRHYTHMIAS_NAME_1:
    count_true += len(dic_list_true[key])
    print('true %s : %d' % (key, len(dic_list_true[key])))
    count_false += len(dic_list_false[key])
    print('false %s : %d' % (key, len(dic_list_false[key])))

    print('')
print('total true : ' + str(count_true))
print('total false : ' + str(count_false))
# Out:
# target record number :  8
# 1. read record : /home/nsc/seers/cardio/database/mc100/SN191016MC100_P004/SN191016MC100_P004 - sample : 256
#   1-1. SN191016MC100_P004-a1 True 0:00:21.351562(5466) *** V-TACH
#   1-1. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a1
#   1-1. load SN191016MC100_P004-a1 Ventricular_Tachycardia True
#   1-2. SN191016MC100_P004-a2 True 0:00:24.042969(6155) *** V-TACH
#   1-2. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a2
#   1-2. load SN191016MC100_P004-a2 Ventricular_Tachycardia True
#   1-3. SN191016MC100_P004-a3 True 0:02:08.199219(32819) *** V-TACH
#   1-3. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a3
#   1-3. load SN191016MC100_P004-a3 Ventricular_Tachycardia True
#   1-4. SN191016MC100_P004-a4 True 0:02:52.410156(44137) *** V-TACH
#   1-4. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a4
#   1-4. load SN191016MC100_P004-a4 Ventricular_Tachycardia True
#   1-5. SN191016MC100_P004-a5 True 0:03:04.101562(47130) *** V-TACH
#   1-5. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a5
#   1-5. load SN191016MC100_P004-a5 Ventricular_Tachycardia True
#   1-6. SN191016MC100_P004-a6 True 0:04:27.265625(68420) *** V-TACH
#   1-6. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a6
#   1-6. load SN191016MC100_P004-a6 Ventricular_Tachycardia True
#   1-7. SN191016MC100_P004-a7 True 0:04:46.050781(73229) *** V-TACH
#   1-7. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a7
#   1-7. load SN191016MC100_P004-a7 Ventricular_Tachycardia True
#   1-8. SN191016MC100_P004-a8 True 0:06:28.269531(99397) *** V-TACH
#   1-8. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a8
#   1-8. load SN191016MC100_P004-a8 Ventricular_Tachycardia True
#   1-9. SN191016MC100_P004-a9 True 0:07:30.015625(115204) *** V-TACH
#   1-9. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a9
#   1-9. load SN191016MC100_P004-a9 Ventricular_Tachycardia True
#   1-10. SN191016MC100_P004-a10 True 0:08:18.937500(127728) *** V-TACH
#   1-10. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a10
#   1-10. load SN191016MC100_P004-a10 Ventricular_Tachycardia True
#   1-11. SN191016MC100_P004-a11 True 0:08:25.437500(129392) *** V-TACH
#   1-11. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a11
#   1-11. load SN191016MC100_P004-a11 Ventricular_Tachycardia True
#   1-12. SN191016MC100_P004-a12 True 0:08:41.265625(133444) *** V-TACH
#   1-12. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a12
#   1-12. load SN191016MC100_P004-a12 Ventricular_Tachycardia True
#   1-13. SN191016MC100_P004-a13 True 0:08:41.949219(133619) *** V-TACH
#   1-13. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a13
#   1-13. load SN191016MC100_P004-a13 Ventricular_Tachycardia True
#   1-14. SN191016MC100_P004-a14 True 0:08:46.796875(134860) *** V-TACH
#   1-14. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a14
#   1-14. load SN191016MC100_P004-a14 Ventricular_Tachycardia True
#   1-15. SN191016MC100_P004-a15 True 0:09:11.253906(141121) *** V-TACH
#   1-15. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a15
#   1-15. load SN191016MC100_P004-a15 Ventricular_Tachycardia True
#   1-16. SN191016MC100_P004-a16 True 0:09:12.167969(141355) *** V-TACH
#   1-16. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a16
#   1-16. load SN191016MC100_P004-a16 Ventricular_Tachycardia True
#   1-17. SN191016MC100_P004-a17 True 0:09:20.261719(143427) *** V-TACH
#   1-17. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a17
#   1-17. load SN191016MC100_P004-a17 Ventricular_Tachycardia True
#   1-18. SN191016MC100_P004-a18 True 0:09:21.046875(143628) *** V-TACH
#   1-18. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a18
#   1-18. load SN191016MC100_P004-a18 Ventricular_Tachycardia True
#   1-19. SN191016MC100_P004-a19 True 0:09:22.761719(144067) *** V-TACH
#   1-19. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a19
#   1-19. load SN191016MC100_P004-a19 Ventricular_Tachycardia True
#   1-20. SN191016MC100_P004-a20 True 0:09:43.429688(149358) *** V-TACH
#   1-20. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a20
#   1-20. load SN191016MC100_P004-a20 Ventricular_Tachycardia True
#   1-21. SN191016MC100_P004-a21 True 0:09:44.464844(149623) *** V-TACH
#   1-21. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a21
#   1-21. load SN191016MC100_P004-a21 Ventricular_Tachycardia True
#   1-22. SN191016MC100_P004-a22 True 0:10:01.640625(154020) *** V-TACH
#   1-22. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a22
#   1-22. load SN191016MC100_P004-a22 Ventricular_Tachycardia True
#   1-23. SN191016MC100_P004-a23 True 0:10:24.941406(159985) *** V-TACH
#   1-23. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a23
#   1-23. load SN191016MC100_P004-a23 Ventricular_Tachycardia True
#   1-24. SN191016MC100_P004-a24 True 0:10:28.078125(160788) *** V-TACH
#   1-24. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a24
#   1-24. load SN191016MC100_P004-a24 Ventricular_Tachycardia True
#   1-25. SN191016MC100_P004-a25 True 0:10:34.484375(162428) *** V-TACH
#   1-25. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a25
#   1-25. load SN191016MC100_P004-a25 Ventricular_Tachycardia True
#   1-26. SN191016MC100_P004-a26 True 0:10:34.882812(162530) *** V-TACH
#   1-26. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a26
#   1-26. load SN191016MC100_P004-a26 Ventricular_Tachycardia True
#   1-27. SN191016MC100_P004-a27 True 0:10:40.460938(163958) *** V-TACH
#   1-27. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a27
#   1-27. load SN191016MC100_P004-a27 Ventricular_Tachycardia True
#   1-28. SN191016MC100_P004-a28 True 0:10:43.410156(164713) *** V-FIB/TACH
#   1-28. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Flutter_Fib/SN191016MC100_P004-a28
#   1-28. load SN191016MC100_P004-a28 Ventricular_Flutter_Fib True
#   1-29. SN191016MC100_P004-a29 True 0:10:49.769531(166341) *** V-TACH
#   1-29. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a29
#   1-29. load SN191016MC100_P004-a29 Ventricular_Tachycardia True
#   1-30. SN191016MC100_P004-a30 True 0:10:50.347656(166489) *** V-TACH
#   1-30. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a30
#   1-30. load SN191016MC100_P004-a30 Ventricular_Tachycardia True
#   1-31. SN191016MC100_P004-a31 True 0:11:12.417969(172139) *** V-TACH
#   1-31. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a31
#   1-31. load SN191016MC100_P004-a31 Ventricular_Tachycardia True
#   1-32. SN191016MC100_P004-a32 True 0:11:13.175781(172333) *** V-TACH
#   1-32. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a32
#   1-32. load SN191016MC100_P004-a32 Ventricular_Tachycardia True
#   1-33. SN191016MC100_P004-a33 True 0:11:18.578125(173716) *** V-TACH
#   1-33. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a33
#   1-33. load SN191016MC100_P004-a33 Ventricular_Tachycardia True
#   1-34. SN191016MC100_P004-a34 True 0:11:22.187500(174640) *** V-TACH
#   1-34. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a34
#   1-34. load SN191016MC100_P004-a34 Ventricular_Tachycardia True
#   1-35. SN191016MC100_P004-a35 True 0:11:25.824219(175571) *** V-TACH
#   1-35. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a35
#   1-35. load SN191016MC100_P004-a35 Ventricular_Tachycardia True
#   1-36. SN191016MC100_P004-a36 True 0:11:29.265625(176452) *** V-TACH
#   1-36. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a36
#   1-36. load SN191016MC100_P004-a36 Ventricular_Tachycardia True
#   1-37. SN191016MC100_P004-a37 True 0:11:32.812500(177360) *** V-TACH
#   1-37. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a37
#   1-37. load SN191016MC100_P004-a37 Ventricular_Tachycardia True
#   1-38. SN191016MC100_P004-a38 True 0:11:36.281250(178248) *** V-TACH
#   1-38. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a38
#   1-38. load SN191016MC100_P004-a38 Ventricular_Tachycardia True
#   1-39. SN191016MC100_P004-a39 True 0:11:39.882812(179170) *** V-TACH
#   1-39. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a39
#   1-39. load SN191016MC100_P004-a39 Ventricular_Tachycardia True
#   1-40. SN191016MC100_P004-a40 True 0:11:46.441406(180849) *** V-TACH
#   1-40. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a40
#   1-40. load SN191016MC100_P004-a40 Ventricular_Tachycardia True
#   1-41. SN191016MC100_P004-a41 True 0:11:47.421875(181100) *** V-TACH
#   1-41. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a41
#   1-41. load SN191016MC100_P004-a41 Ventricular_Tachycardia True
#   1-42. SN191016MC100_P004-a42 True 0:11:49.597656(181657) *** V-TACH
#   1-42. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a42
#   1-42. load SN191016MC100_P004-a42 Ventricular_Tachycardia True
#   1-43. SN191016MC100_P004-a43 True 0:11:50.421875(181868) *** V-TACH
#   1-43. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a43
#   1-43. load SN191016MC100_P004-a43 Ventricular_Tachycardia True
#   1-44. SN191016MC100_P004-a44 True 0:11:55.320312(183122) *** V-TACH
#   1-44. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a44
#   1-44. load SN191016MC100_P004-a44 Ventricular_Tachycardia True
#   1-45. SN191016MC100_P004-a45 True 0:11:56.117188(183326) *** V-TACH
#   1-45. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a45
#   1-45. load SN191016MC100_P004-a45 Ventricular_Tachycardia True
#   1-46. SN191016MC100_P004-a46 True 0:12:00.882812(184546) *** V-TACH
#   1-46. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a46
#   1-46. load SN191016MC100_P004-a46 Ventricular_Tachycardia True
#   1-47. SN191016MC100_P004-a47 True 0:12:01.722656(184761) *** V-TACH
#   1-47. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a47
#   1-47. load SN191016MC100_P004-a47 Ventricular_Tachycardia True
#   1-48. SN191016MC100_P004-a48 True 0:12:06.484375(185980) *** V-TACH
#   1-48. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a48
#   1-48. load SN191016MC100_P004-a48 Ventricular_Tachycardia True
#   1-49. SN191016MC100_P004-a49 True 0:12:07.324219(186195) *** V-TACH
#   1-49. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a49
#   1-49. load SN191016MC100_P004-a49 Ventricular_Tachycardia True
#   1-50. SN191016MC100_P004-a50 True 0:12:12.226562(187450) *** V-TACH
#   1-50. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a50
#   1-50. load SN191016MC100_P004-a50 Ventricular_Tachycardia True
#   1-51. SN191016MC100_P004-a51 True 0:12:15.906250(188392) *** V-TACH
#   1-51. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a51
#   1-51. load SN191016MC100_P004-a51 Ventricular_Tachycardia True
#   1-52. SN191016MC100_P004-a52 True 0:12:19.546875(189324) *** V-TACH
#   1-52. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a52
#   1-52. load SN191016MC100_P004-a52 Ventricular_Tachycardia True
#   1-53. SN191016MC100_P004-a53 True 0:12:22.925781(190189) *** V-TACH
#   1-53. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a53
#   1-53. load SN191016MC100_P004-a53 Ventricular_Tachycardia True
#   1-54. SN191016MC100_P004-a54 True 0:12:38.839844(194263) *** V-TACH
#   1-54. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a54
#   1-54. load SN191016MC100_P004-a54 Ventricular_Tachycardia True
#   1-55. SN191016MC100_P004-a55 True 0:12:45.476562(195962) *** V-TACH
#   1-55. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a55
#   1-55. load SN191016MC100_P004-a55 Ventricular_Tachycardia True
#   1-56. SN191016MC100_P004-a56 True 0:12:48.976562(196858) *** V-TACH
#   1-56. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a56
#   1-56. load SN191016MC100_P004-a56 Ventricular_Tachycardia True
#   1-57. SN191016MC100_P004-a57 True 0:12:52.617188(197790) *** V-TACH
#   1-57. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a57
#   1-57. load SN191016MC100_P004-a57 Ventricular_Tachycardia True
#   1-58. SN191016MC100_P004-a58 True 0:12:56.218750(198712) *** V-TACH
#   1-58. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a58
#   1-58. load SN191016MC100_P004-a58 Ventricular_Tachycardia True
#   1-59. SN191016MC100_P004-a59 True 0:12:59.648438(199590) *** V-TACH
#   1-59. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a59
#   1-59. load SN191016MC100_P004-a59 Ventricular_Tachycardia True
#   1-60. SN191016MC100_P004-a60 True 0:13:00.351562(199770) *** V-TACH
#   1-60. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a60
#   1-60. load SN191016MC100_P004-a60 Ventricular_Tachycardia True
#   1-61. SN191016MC100_P004-a61 True 0:13:05.175781(201005) *** V-TACH
#   1-61. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a61
#   1-61. load SN191016MC100_P004-a61 Ventricular_Tachycardia True
#   1-62. SN191016MC100_P004-a62 True 0:13:08.820312(201938) *** V-TACH
#   1-62. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a62
#   1-62. load SN191016MC100_P004-a62 Ventricular_Tachycardia True
#   1-63. SN191016MC100_P004-a63 True 0:13:12.335938(202838) *** V-TACH
#   1-63. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a63
#   1-63. load SN191016MC100_P004-a63 Ventricular_Tachycardia True
#   1-64. SN191016MC100_P004-a64 True 0:13:15.804688(203726) *** V-TACH
#   1-64. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a64
#   1-64. load SN191016MC100_P004-a64 Ventricular_Tachycardia True
#   1-65. SN191016MC100_P004-a65 True 0:13:19.359375(204636) *** V-TACH
#   1-65. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a65
#   1-65. load SN191016MC100_P004-a65 Ventricular_Tachycardia True
#   1-66. SN191016MC100_P004-a66 True 0:13:22.796875(205516) *** V-TACH
#   1-66. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a66
#   1-66. load SN191016MC100_P004-a66 Ventricular_Tachycardia True
#   1-67. SN191016MC100_P004-a67 True 0:13:26.464844(206455) *** V-TACH
#   1-67. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a67
#   1-67. load SN191016MC100_P004-a67 Ventricular_Tachycardia True
#   1-68. SN191016MC100_P004-a68 True 0:13:29.812500(207312) *** V-TACH
#   1-68. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a68
#   1-68. load SN191016MC100_P004-a68 Ventricular_Tachycardia True
#   1-69. SN191016MC100_P004-a69 True 0:13:33.343750(208216) *** V-TACH
#   1-69. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a69
#   1-69. load SN191016MC100_P004-a69 Ventricular_Tachycardia True
#   1-70. SN191016MC100_P004-a70 True 0:13:36.656250(209064) *** V-TACH
#   1-70. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a70
#   1-70. load SN191016MC100_P004-a70 Ventricular_Tachycardia True
#   1-71. SN191016MC100_P004-a71 True 0:13:40.066406(209937) *** V-TACH
#   1-71. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a71
#   1-71. load SN191016MC100_P004-a71 Ventricular_Tachycardia True
#   1-72. SN191016MC100_P004-a72 True 0:13:43.648438(210854) *** V-TACH
#   1-72. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a72
#   1-72. load SN191016MC100_P004-a72 Ventricular_Tachycardia True
#   1-73. SN191016MC100_P004-a73 True 0:13:47.136719(211747) *** V-TACH
#   1-73. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a73
#   1-73. load SN191016MC100_P004-a73 Ventricular_Tachycardia True
#   1-74. SN191016MC100_P004-a74 True 0:13:50.765625(212676) *** V-TACH
#   1-74. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a74
#   1-74. load SN191016MC100_P004-a74 Ventricular_Tachycardia True
#   1-75. SN191016MC100_P004-a75 True 0:13:54.132812(213538) *** V-TACH
#   1-75. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a75
#   1-75. load SN191016MC100_P004-a75 Ventricular_Tachycardia True
#   1-76. SN191016MC100_P004-a76 True 0:13:57.800781(214477) *** V-TACH
#   1-76. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a76
#   1-76. load SN191016MC100_P004-a76 Ventricular_Tachycardia True
#   1-77. SN191016MC100_P004-a77 True 0:14:01.343750(215384) *** V-TACH
#   1-77. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a77
#   1-77. load SN191016MC100_P004-a77 Ventricular_Tachycardia True
#   1-78. SN191016MC100_P004-a78 True 0:14:04.699219(216243) *** V-TACH
#   1-78. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a78
#   1-78. load SN191016MC100_P004-a78 Ventricular_Tachycardia True
#   1-79. SN191016MC100_P004-a79 True 0:14:08.148438(217126) *** V-TACH
#   1-79. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a79
#   1-79. load SN191016MC100_P004-a79 Ventricular_Tachycardia True
#   1-80. SN191016MC100_P004-a80 True 0:14:11.507812(217986) *** V-TACH
#   1-80. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a80
#   1-80. load SN191016MC100_P004-a80 Ventricular_Tachycardia True
#   1-81. SN191016MC100_P004-a81 True 0:14:15.062500(218896) *** V-TACH
#   1-81. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a81
#   1-81. load SN191016MC100_P004-a81 Ventricular_Tachycardia True
#   1-82. SN191016MC100_P004-a82 True 0:14:18.523438(219782) *** V-TACH
#   1-82. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a82
#   1-82. load SN191016MC100_P004-a82 Ventricular_Tachycardia True
#   1-83. SN191016MC100_P004-a83 True 0:14:22.035156(220681) *** V-TACH
#   1-83. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a83
#   1-83. load SN191016MC100_P004-a83 Ventricular_Tachycardia True
#   1-84. SN191016MC100_P004-a84 True 0:14:27.292969(222027) *** V-TACH
#   1-84. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a84
#   1-84. load SN191016MC100_P004-a84 Ventricular_Tachycardia True
#   1-85. SN191016MC100_P004-a85 True 0:14:33.675781(223661) *** V-TACH
#   1-85. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a85
#   1-85. load SN191016MC100_P004-a85 Ventricular_Tachycardia True
#   1-86. SN191016MC100_P004-a86 True 0:14:37.136719(224547) *** V-TACH
#   1-86. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a86
#   1-86. load SN191016MC100_P004-a86 Ventricular_Tachycardia True
#   1-87. SN191016MC100_P004-a87 True 0:14:43.585938(226198) *** V-TACH
#   1-87. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a87
#   1-87. load SN191016MC100_P004-a87 Ventricular_Tachycardia True
#   1-88. SN191016MC100_P004-a88 True 0:14:50.035156(227849) *** V-TACH
#   1-88. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a88
#   1-88. load SN191016MC100_P004-a88 Ventricular_Tachycardia True
#   1-89. SN191016MC100_P004-a89 True 0:14:57.937500(229872) *** V-TACH
#   1-89. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a89
#   1-89. load SN191016MC100_P004-a89 Ventricular_Tachycardia True
#   1-90. SN191016MC100_P004-a90 True 0:15:05.628906(231841) *** V-TACH
#   1-90. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a90
#   1-90. load SN191016MC100_P004-a90 Ventricular_Tachycardia True
#   1-91. SN191016MC100_P004-a91 True 0:15:08.937500(232688) *** V-TACH
#   1-91. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a91
#   1-91. load SN191016MC100_P004-a91 Ventricular_Tachycardia True
#   1-92. SN191016MC100_P004-a92 True 0:15:09.460938(232822) *** V-TACH
#   1-92. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a92
#   1-92. load SN191016MC100_P004-a92 Ventricular_Tachycardia True
#   1-93. SN191016MC100_P004-a93 True 0:15:16.886719(234723) *** V-TACH
#   1-93. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a93
#   1-93. load SN191016MC100_P004-a93 Ventricular_Tachycardia True
#   1-94. SN191016MC100_P004-a94 True 0:15:21.699219(235955) *** V-TACH
#   1-94. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a94
#   1-94. load SN191016MC100_P004-a94 Ventricular_Tachycardia True
#   1-95. SN191016MC100_P004-a95 True 0:15:26.617188(237214) *** V-TACH
#   1-95. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a95
#   1-95. load SN191016MC100_P004-a95 Ventricular_Tachycardia True
#   1-96. SN191016MC100_P004-a96 True 0:15:31.316406(238417) *** V-TACH
#   1-96. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a96
#   1-96. load SN191016MC100_P004-a96 Ventricular_Tachycardia True
#   1-97. SN191016MC100_P004-a97 True 0:15:32.054688(238606) *** V-TACH
#   1-97. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a97
#   1-97. load SN191016MC100_P004-a97 Ventricular_Tachycardia True
#   1-98. SN191016MC100_P004-a98 True 0:15:36.773438(239814) *** V-TACH
#   1-98. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a98
#   1-98. load SN191016MC100_P004-a98 Ventricular_Tachycardia True
#   1-99. SN191016MC100_P004-a99 True 0:15:40.300781(240717) *** V-TACH
#   1-99. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a99
#   1-99. load SN191016MC100_P004-a99 Ventricular_Tachycardia True
#   1-100. SN191016MC100_P004-a100 True 0:15:43.785156(241609) *** V-TACH
#   1-100. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a100
#   1-100. load SN191016MC100_P004-a100 Ventricular_Tachycardia True
#   1-101. SN191016MC100_P004-a101 True 0:15:47.160156(242473) *** V-TACH
#   1-101. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a101
#   1-101. load SN191016MC100_P004-a101 Ventricular_Tachycardia True
#   1-102. SN191016MC100_P004-a102 True 0:15:50.722656(243385) *** V-TACH
#   1-102. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a102
#   1-102. load SN191016MC100_P004-a102 Ventricular_Tachycardia True
#   1-103. SN191016MC100_P004-a103 True 0:15:54.171875(244268) *** V-TACH
#   1-103. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a103
#   1-103. load SN191016MC100_P004-a103 Ventricular_Tachycardia True
#   1-104. SN191016MC100_P004-a104 True 0:15:57.816406(245201) *** V-TACH
#   1-104. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a104
#   1-104. load SN191016MC100_P004-a104 Ventricular_Tachycardia True
#   1-105. SN191016MC100_P004-a105 True 0:16:01.343750(246104) *** V-TACH
#   1-105. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a105
#   1-105. load SN191016MC100_P004-a105 Ventricular_Tachycardia True
#   1-106. SN191016MC100_P004-a106 True 0:16:04.738281(246973) *** V-TACH
#   1-106. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a106
#   1-106. load SN191016MC100_P004-a106 Ventricular_Tachycardia True
#   1-107. SN191016MC100_P004-a107 True 0:16:08.187500(247856) *** V-TACH
#   1-107. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a107
#   1-107. load SN191016MC100_P004-a107 Ventricular_Tachycardia True
#   1-108. SN191016MC100_P004-a108 True 0:16:11.527344(248711) *** V-TACH
#   1-108. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a108
#   1-108. load SN191016MC100_P004-a108 Ventricular_Tachycardia True
#   1-109. SN191016MC100_P004-a109 True 0:16:15.113281(249629) *** V-TACH
#   1-109. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a109
#   1-109. load SN191016MC100_P004-a109 Ventricular_Tachycardia True
#   1-110. SN191016MC100_P004-a110 True 0:16:18.507812(250498) *** V-TACH
#   1-110. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a110
#   1-110. load SN191016MC100_P004-a110 Ventricular_Tachycardia True
#   1-111. SN191016MC100_P004-a111 True 0:16:22.015625(251396) *** V-TACH
#   1-111. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a111
#   1-111. load SN191016MC100_P004-a111 Ventricular_Tachycardia True
#   1-112. SN191016MC100_P004-a112 True 0:16:25.425781(252269) *** V-TACH
#   1-112. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a112
#   1-112. load SN191016MC100_P004-a112 Ventricular_Tachycardia True
#   1-113. SN191016MC100_P004-a113 True 0:16:28.812500(253136) *** V-TACH
#   1-113. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a113
#   1-113. load SN191016MC100_P004-a113 Ventricular_Tachycardia True
#   1-114. SN191016MC100_P004-a114 True 0:16:32.292969(254027) *** V-TACH
#   1-114. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a114
#   1-114. load SN191016MC100_P004-a114 Ventricular_Tachycardia True
#   1-115. SN191016MC100_P004-a115 True 0:16:35.687500(254896) *** V-TACH
#   1-115. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a115
#   1-115. load SN191016MC100_P004-a115 Ventricular_Tachycardia True
#   1-116. SN191016MC100_P004-a116 True 0:16:39.195312(255794) *** V-TACH
#   1-116. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a116
#   1-116. load SN191016MC100_P004-a116 Ventricular_Tachycardia True
#   1-117. SN191016MC100_P004-a117 True 0:16:42.464844(256631) *** V-TACH
#   1-117. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a117
#   1-117. load SN191016MC100_P004-a117 Ventricular_Tachycardia True
#   1-118. SN191016MC100_P004-a118 True 0:16:45.921875(257516) *** V-TACH
#   1-118. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a118
#   1-118. load SN191016MC100_P004-a118 Ventricular_Tachycardia True
#   1-119. SN191016MC100_P004-a119 True 0:16:49.433594(258415) *** V-TACH
#   1-119. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a119
#   1-119. load SN191016MC100_P004-a119 Ventricular_Tachycardia True
#   1-120. SN191016MC100_P004-a120 True 0:16:52.894531(259301) *** V-TACH
#   1-120. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a120
#   1-120. load SN191016MC100_P004-a120 Ventricular_Tachycardia True
#   1-121. SN191016MC100_P004-a121 True 0:16:56.421875(260204) *** V-TACH
#   1-121. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a121
#   1-121. load SN191016MC100_P004-a121 Ventricular_Tachycardia True
#   1-122. SN191016MC100_P004-a122 True 0:16:59.785156(261065) *** V-TACH
#   1-122. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a122
#   1-122. load SN191016MC100_P004-a122 Ventricular_Tachycardia True
#   1-123. SN191016MC100_P004-a123 True 0:17:03.312500(261968) *** V-TACH
#   1-123. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a123
#   1-123. load SN191016MC100_P004-a123 Ventricular_Tachycardia True
#   1-124. SN191016MC100_P004-a124 True 0:17:06.753906(262849) *** V-TACH
#   1-124. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a124
#   1-124. load SN191016MC100_P004-a124 Ventricular_Tachycardia True
#   1-125. SN191016MC100_P004-a125 True 0:17:10.148438(263718) *** V-TACH
#   1-125. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a125
#   1-125. load SN191016MC100_P004-a125 Ventricular_Tachycardia True
#   1-126. SN191016MC100_P004-a126 True 0:17:13.632812(264610) *** V-TACH
#   1-126. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a126
#   1-126. load SN191016MC100_P004-a126 Ventricular_Tachycardia True
#   1-127. SN191016MC100_P004-a127 True 0:17:16.816406(265425) *** V-TACH
#   1-127. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a127
#   1-127. load SN191016MC100_P004-a127 Ventricular_Tachycardia True
#   1-128. SN191016MC100_P004-a128 True 0:17:21.570312(266642) *** V-TACH
#   1-128. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a128
#   1-128. load SN191016MC100_P004-a128 Ventricular_Tachycardia True
#   1-129. SN191016MC100_P004-a129 True 0:17:26.335938(267862) *** V-TACH
#   1-129. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a129
#   1-129. load SN191016MC100_P004-a129 Ventricular_Tachycardia True
#   1-130. SN191016MC100_P004-a130 True 0:17:30.980469(269051) *** V-TACH
#   1-130. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a130
#   1-130. load SN191016MC100_P004-a130 Ventricular_Tachycardia True
#   1-131. SN191016MC100_P004-a131 True 0:17:35.585938(270230) *** V-TACH
#   1-131. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a131
#   1-131. load SN191016MC100_P004-a131 Ventricular_Tachycardia True
#   1-132. SN191016MC100_P004-a132 True 0:17:40.226562(271418) *** V-TACH
#   1-132. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a132
#   1-132. load SN191016MC100_P004-a132 Ventricular_Tachycardia True
#   1-133. SN191016MC100_P004-a133 True 0:17:44.953125(272628) *** V-TACH
#   1-133. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a133
#   1-133. load SN191016MC100_P004-a133 Ventricular_Tachycardia True
#   1-134. SN191016MC100_P004-a134 True 0:17:45.476562(272762) *** V-TACH
#   1-134. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a134
#   1-134. load SN191016MC100_P004-a134 Ventricular_Tachycardia True
#   1-135. SN191016MC100_P004-a135 True 0:17:49.753906(273857) *** V-TACH
#   1-135. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a135
#   1-135. load SN191016MC100_P004-a135 Ventricular_Tachycardia True
#   1-136. SN191016MC100_P004-a136 True 0:17:54.472656(275065) *** V-TACH
#   1-136. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a136
#   1-136. load SN191016MC100_P004-a136 Ventricular_Tachycardia True
#   1-137. SN191016MC100_P004-a137 True 0:17:59.113281(276253) *** V-TACH
#   1-137. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a137
#   1-137. load SN191016MC100_P004-a137 Ventricular_Tachycardia True
#   1-138. SN191016MC100_P004-a138 True 0:18:03.804688(277454) *** V-TACH
#   1-138. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a138
#   1-138. load SN191016MC100_P004-a138 Ventricular_Tachycardia True
#   1-139. SN191016MC100_P004-a139 True 0:18:08.546875(278668) *** V-TACH
#   1-139. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a139
#   1-139. load SN191016MC100_P004-a139 Ventricular_Tachycardia True
#   1-140. SN191016MC100_P004-a140 True 0:18:13.222656(279865) *** V-TACH
#   1-140. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a140
#   1-140. load SN191016MC100_P004-a140 Ventricular_Tachycardia True
#   1-141. SN191016MC100_P004-a141 True 0:18:17.960938(281078) *** V-TACH
#   1-141. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a141
#   1-141. load SN191016MC100_P004-a141 Ventricular_Tachycardia True
#   1-142. SN191016MC100_P004-a142 True 0:18:21.519531(281989) *** V-TACH
#   1-142. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a142
#   1-142. load SN191016MC100_P004-a142 Ventricular_Tachycardia True
#   1-143. SN191016MC100_P004-a143 True 0:18:23.265625(282436) *** V-TACH
#   1-143. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a143
#   1-143. load SN191016MC100_P004-a143 Ventricular_Tachycardia True
#   1-144. SN191016MC100_P004-a144 True 0:18:26.769531(283333) *** V-TACH
#   1-144. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a144
#   1-144. load SN191016MC100_P004-a144 Ventricular_Tachycardia True
#   1-145. SN191016MC100_P004-a145 True 0:18:30.160156(284201) *** V-TACH
#   1-145. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a145
#   1-145. load SN191016MC100_P004-a145 Ventricular_Tachycardia True
#   1-146. SN191016MC100_P004-a146 True 0:18:33.777344(285127) *** V-TACH
#   1-146. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a146
#   1-146. load SN191016MC100_P004-a146 Ventricular_Tachycardia True
#   1-147. SN191016MC100_P004-a147 True 0:18:37.062500(285968) *** V-TACH
#   1-147. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a147
#   1-147. load SN191016MC100_P004-a147 Ventricular_Tachycardia True
#   1-148. SN191016MC100_P004-a148 True 0:18:42.273438(287302) *** V-TACH
#   1-148. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a148
#   1-148. load SN191016MC100_P004-a148 Ventricular_Tachycardia True
#   1-149. SN191016MC100_P004-a149 True 0:18:45.644531(288165) *** V-TACH
#   1-149. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a149
#   1-149. load SN191016MC100_P004-a149 Ventricular_Tachycardia True
#   1-150. SN191016MC100_P004-a150 True 0:18:53.097656(290073) *** V-TACH
#   1-150. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a150
#   1-150. load SN191016MC100_P004-a150 Ventricular_Tachycardia True
#   1-151. SN191016MC100_P004-a151 True 0:19:05.226562(293178) *** V-TACH
#   1-151. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a151
#   1-151. load SN191016MC100_P004-a151 Ventricular_Tachycardia True
#   1-152. SN191016MC100_P004-a152 True 0:19:22.441406(297585) *** V-TACH
#   1-152. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a152
#   1-152. load SN191016MC100_P004-a152 Ventricular_Tachycardia True
#   1-153. SN191016MC100_P004-a153 True 0:19:23.054688(297742) *** V-TACH
#   1-153. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a153
#   1-153. load SN191016MC100_P004-a153 Ventricular_Tachycardia True
#   1-154. SN191016MC100_P004-a154 True 0:19:27.792969(298955) *** V-TACH
#   1-154. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a154
#   1-154. load SN191016MC100_P004-a154 Ventricular_Tachycardia True
#   1-155. SN191016MC100_P004-a155 True 0:19:31.156250(299816) *** V-TACH
#   1-155. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a155
#   1-155. load SN191016MC100_P004-a155 Ventricular_Tachycardia True
#   1-156. SN191016MC100_P004-a156 True 0:19:34.625000(300704) *** V-TACH
#   1-156. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a156
#   1-156. load SN191016MC100_P004-a156 Ventricular_Tachycardia True
#   1-157. SN191016MC100_P004-a157 True 0:19:38.105469(301595) *** V-TACH
#   1-157. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a157
#   1-157. load SN191016MC100_P004-a157 Ventricular_Tachycardia True
#   1-158. SN191016MC100_P004-a158 True 0:19:41.542969(302475) *** V-TACH
#   1-158. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a158
#   1-158. load SN191016MC100_P004-a158 Ventricular_Tachycardia True
#   1-159. SN191016MC100_P004-a159 True 0:19:48.261719(304195) *** V-TACH
#   1-159. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a159
#   1-159. load SN191016MC100_P004-a159 Ventricular_Tachycardia True
#   1-160. SN191016MC100_P004-a160 True 0:19:51.800781(305101) *** V-TACH
#   1-160. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a160
#   1-160. load SN191016MC100_P004-a160 Ventricular_Tachycardia True
#   1-161. SN191016MC100_P004-a161 True 0:19:55.175781(305965) *** V-TACH
#   1-161. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a161
#   1-161. load SN191016MC100_P004-a161 Ventricular_Tachycardia True
#   1-162. SN191016MC100_P004-a162 True 0:19:58.671875(306860) *** V-TACH
#   1-162. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a162
#   1-162. load SN191016MC100_P004-a162 Ventricular_Tachycardia True
#   1-163. SN191016MC100_P004-a163 True 0:19:59.304688(307022) *** V-TACH
#   1-163. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a163
#   1-163. load SN191016MC100_P004-a163 Ventricular_Tachycardia True
#   1-164. SN191016MC100_P004-a164 True 0:20:04.097656(308249) *** V-TACH
#   1-164. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a164
#   1-164. load SN191016MC100_P004-a164 Ventricular_Tachycardia True
#   1-165. SN191016MC100_P004-a165 True 0:20:10.976562(310010) *** V-TACH
#   1-165. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a165
#   1-165. load SN191016MC100_P004-a165 Ventricular_Tachycardia True
#   1-166. SN191016MC100_P004-a166 True 0:20:12.675781(310445) *** V-TACH
#   1-166. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a166
#   1-166. load SN191016MC100_P004-a166 Ventricular_Tachycardia True
#   1-167. SN191016MC100_P004-a167 True 0:20:16.160156(311337) *** V-TACH
#   1-167. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a167
#   1-167. load SN191016MC100_P004-a167 Ventricular_Tachycardia True
#   1-168. SN191016MC100_P004-a168 True 0:20:19.691406(312241) *** V-TACH
#   1-168. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a168
#   1-168. load SN191016MC100_P004-a168 Ventricular_Tachycardia True
#   1-169. SN191016MC100_P004-a169 True 0:20:23.167969(313131) *** V-TACH
#   1-169. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a169
#   1-169. load SN191016MC100_P004-a169 Ventricular_Tachycardia True
#   1-170. SN191016MC100_P004-a170 True 0:20:36.882812(316642) *** V-TACH
#   1-170. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a170
#   1-170. load SN191016MC100_P004-a170 Ventricular_Tachycardia True
#   1-171. SN191016MC100_P004-a171 True 0:21:10.058594(325135) *** V-TACH
#   1-171. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a171
#   1-171. load SN191016MC100_P004-a171 Ventricular_Tachycardia True
#   1-172. SN191016MC100_P004-a172 True 0:21:14.308594(326223) *** V-TACH
#   1-172. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a172
#   1-172. load SN191016MC100_P004-a172 Ventricular_Tachycardia True
#   1-173. SN191016MC100_P004-a173 True 0:21:23.210938(328502) *** V-TACH
#   1-173. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a173
#   1-173. load SN191016MC100_P004-a173 Ventricular_Tachycardia True
#   1-174. SN191016MC100_P004-a174 True 0:21:35.625000(331680) *** V-TACH
#   1-174. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a174
#   1-174. load SN191016MC100_P004-a174 Ventricular_Tachycardia True
#   1-175. SN191016MC100_P004-a175 True 0:21:39.144531(332581) *** V-TACH
#   1-175. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a175
#   1-175. load SN191016MC100_P004-a175 Ventricular_Tachycardia True
#   1-176. SN191016MC100_P004-a176 True 0:21:43.265625(333636) *** V-TACH
#   1-176. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a176
#   1-176. load SN191016MC100_P004-a176 Ventricular_Tachycardia True
#   1-177. SN191016MC100_P004-a177 True 0:22:04.687500(339120) *** V-TACH
#   1-177. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a177
#   1-177. load SN191016MC100_P004-a177 Ventricular_Tachycardia True
#   1-178. SN191016MC100_P004-a178 True 0:22:12.425781(341101) *** V-TACH
#   1-178. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a178
#   1-178. load SN191016MC100_P004-a178 Ventricular_Tachycardia True
#   1-179. SN191016MC100_P004-a179 True 0:22:17.085938(342294) *** V-TACH
#   1-179. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a179
#   1-179. load SN191016MC100_P004-a179 Ventricular_Tachycardia True
#   1-180. SN191016MC100_P004-a180 True 0:22:18.992188(342782) *** V-TACH
#   1-180. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a180
#   1-180. load SN191016MC100_P004-a180 Ventricular_Tachycardia True
#   1-181. SN191016MC100_P004-a181 True 0:22:23.660156(343977) *** V-TACH
#   1-181. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a181
#   1-181. load SN191016MC100_P004-a181 Ventricular_Tachycardia True
#   1-182. SN191016MC100_P004-a182 True 0:22:24.382812(344162) *** V-TACH
#   1-182. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a182
#   1-182. load SN191016MC100_P004-a182 Ventricular_Tachycardia True
#   1-183. SN191016MC100_P004-a183 True 0:22:35.738281(347069) *** V-TACH
#   1-183. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a183
#   1-183. load SN191016MC100_P004-a183 Ventricular_Tachycardia True
#   1-184. SN191016MC100_P004-a184 True 0:22:39.921875(348140) *** V-TACH
#   1-184. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a184
#   1-184. load SN191016MC100_P004-a184 Ventricular_Tachycardia True
#   1-185. SN191016MC100_P004-a185 True 0:22:44.714844(349367) *** V-TACH
#   1-185. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a185
#   1-185. load SN191016MC100_P004-a185 Ventricular_Tachycardia True
#   1-186. SN191016MC100_P004-a186 True 0:22:45.351562(349530) *** V-TACH
#   1-186. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a186
#   1-186. load SN191016MC100_P004-a186 Ventricular_Tachycardia True
#   1-187. SN191016MC100_P004-a187 True 0:22:50.144531(350757) *** V-TACH
#   1-187. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a187
#   1-187. load SN191016MC100_P004-a187 Ventricular_Tachycardia True
#   1-188. SN191016MC100_P004-a188 True 0:22:53.625000(351648) *** V-TACH
#   1-188. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P004-a188
#   1-188. load SN191016MC100_P004-a188 Ventricular_Tachycardia True
# ...
#   8-867. load SN191016MC100_P003-a867 Ventricular_Tachycardia True
#   8-868. SN191016MC100_P003-a868 True 0:28:01.027344(430343) *** V-TACH
#   8-868. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a868
#   8-868. load SN191016MC100_P003-a868 Ventricular_Tachycardia True
#   8-869. SN191016MC100_P003-a869 True 0:28:02.640625(430756) *** V-TACH
#   8-869. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a869
#   8-869. load SN191016MC100_P003-a869 Ventricular_Tachycardia True
#   8-870. SN191016MC100_P003-a870 True 0:28:06.687500(431792) *** V-TACH
#   8-870. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a870
#   8-870. load SN191016MC100_P003-a870 Ventricular_Tachycardia True
#   8-871. SN191016MC100_P003-a871 True 0:28:08.019531(432133) *** V-TACH
#   8-871. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a871
#   8-871. load SN191016MC100_P003-a871 Ventricular_Tachycardia True
#   8-872. SN191016MC100_P003-a872 True 0:28:09.296875(432460) *** V-TACH
#   8-872. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a872
#   8-872. load SN191016MC100_P003-a872 Ventricular_Tachycardia True
#   8-873. SN191016MC100_P003-a873 True 0:28:11(432896) *** V-TACH
#   8-873. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a873
#   8-873. load SN191016MC100_P003-a873 Ventricular_Tachycardia True
#   8-874. SN191016MC100_P003-a874 True 0:28:14.292969(433739) *** V-TACH
#   8-874. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a874
#   8-874. load SN191016MC100_P003-a874 Ventricular_Tachycardia True
#   8-875. SN191016MC100_P003-a875 True 0:28:15.625000(434080) *** V-TACH
#   8-875. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a875
#   8-875. load SN191016MC100_P003-a875 Ventricular_Tachycardia True
#   8-876. SN191016MC100_P003-a876 True 0:28:17.324219(434515) *** V-TACH
#   8-876. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a876
#   8-876. load SN191016MC100_P003-a876 Ventricular_Tachycardia True
#   8-877. SN191016MC100_P003-a877 True 0:28:19.703125(435124) *** V-TACH
#   8-877. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a877
#   8-877. load SN191016MC100_P003-a877 Ventricular_Tachycardia True
#   8-878. SN191016MC100_P003-a878 True 0:28:20.191406(435249) *** V-TACH
#   8-878. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a878
#   8-878. load SN191016MC100_P003-a878 Ventricular_Tachycardia True
#   8-879. SN191016MC100_P003-a879 True 0:28:21.890625(435684) *** V-TACH
#   8-879. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a879
#   8-879. load SN191016MC100_P003-a879 Ventricular_Tachycardia True
#   8-880. SN191016MC100_P003-a880 True 0:28:25.156250(436520) *** V-TACH
#   8-880. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a880
#   8-880. load SN191016MC100_P003-a880 Ventricular_Tachycardia True
#   8-881. SN191016MC100_P003-a881 True 0:28:26.535156(436873) *** V-TACH
#   8-881. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a881
#   8-881. load SN191016MC100_P003-a881 Ventricular_Tachycardia True
#   8-882. SN191016MC100_P003-a882 True 0:28:28.273438(437318) *** V-TACH
#   8-882. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a882
#   8-882. load SN191016MC100_P003-a882 Ventricular_Tachycardia True
#   8-883. SN191016MC100_P003-a883 True 0:28:31.738281(438205) *** V-TACH
#   8-883. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a883
#   8-883. load SN191016MC100_P003-a883 Ventricular_Tachycardia True
#   8-884. SN191016MC100_P003-a884 True 0:28:32.394531(438373) *** V-TACH
#   8-884. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a884
#   8-884. load SN191016MC100_P003-a884 Ventricular_Tachycardia True
#   8-885. SN191016MC100_P003-a885 True 0:28:32.949219(438515) *** V-TACH
#   8-885. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a885
#   8-885. load SN191016MC100_P003-a885 Ventricular_Tachycardia True
#   8-886. SN191016MC100_P003-a886 True 0:28:34.445312(438898) *** V-TACH
#   8-886. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a886
#   8-886. load SN191016MC100_P003-a886 Ventricular_Tachycardia True
#   8-887. SN191016MC100_P003-a887 True 0:28:36.152344(439335) *** V-TACH
#   8-887. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a887
#   8-887. load SN191016MC100_P003-a887 Ventricular_Tachycardia True
#   8-888. SN191016MC100_P003-a888 True 0:28:37.882812(439778) *** V-TACH
#   8-888. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a888
#   8-888. load SN191016MC100_P003-a888 Ventricular_Tachycardia True
#   8-889. SN191016MC100_P003-a889 True 0:28:46.687500(442032) *** V-TACH
#   8-889. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a889
#   8-889. load SN191016MC100_P003-a889 Ventricular_Tachycardia True
#   8-890. SN191016MC100_P003-a890 True 0:28:48.179688(442414) *** V-TACH
#   8-890. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a890
#   8-890. load SN191016MC100_P003-a890 Ventricular_Tachycardia True
#   8-891. SN191016MC100_P003-a891 True 0:28:49.734375(442812) *** V-TACH
#   8-891. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a891
#   8-891. load SN191016MC100_P003-a891 Ventricular_Tachycardia True
#   8-892. SN191016MC100_P003-a892 True 0:28:51.363281(443229) *** V-TACH
#   8-892. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a892
#   8-892. load SN191016MC100_P003-a892 Ventricular_Tachycardia True
#   8-893. SN191016MC100_P003-a893 True 0:28:52.023438(443398) *** V-TACH
#   8-893. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a893
#   8-893. load SN191016MC100_P003-a893 Ventricular_Tachycardia True
#   8-894. SN191016MC100_P003-a894 True 0:28:54.191406(443953) *** V-TACH
#   8-894. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a894
#   8-894. load SN191016MC100_P003-a894 Ventricular_Tachycardia True
#   8-895. SN191016MC100_P003-a895 True 0:28:55.703125(444340) *** V-TACH
#   8-895. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a895
#   8-895. load SN191016MC100_P003-a895 Ventricular_Tachycardia True
#   8-896. SN191016MC100_P003-a896 True 0:28:59.843750(445400) *** V-TACH
#   8-896. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a896
#   8-896. load SN191016MC100_P003-a896 Ventricular_Tachycardia True
#   8-897. SN191016MC100_P003-a897 True 0:29:10.675781(448173) *** V-TACH
#   8-897. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a897
#   8-897. load SN191016MC100_P003-a897 Ventricular_Tachycardia True
#   8-898. SN191016MC100_P003-a898 True 0:29:12.242188(448574) *** V-TACH
#   8-898. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a898
#   8-898. load SN191016MC100_P003-a898 Ventricular_Tachycardia True
#   8-899. SN191016MC100_P003-a899 True 0:29:13.867188(448990) *** V-TACH
#   8-899. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a899
#   8-899. load SN191016MC100_P003-a899 Ventricular_Tachycardia True
#   8-900. SN191016MC100_P003-a900 True 0:29:16.976562(449786) *** V-TACH
#   8-900. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a900
#   8-900. load SN191016MC100_P003-a900 Ventricular_Tachycardia True
#   8-901. SN191016MC100_P003-a901 True 0:29:18.527344(450183) *** V-TACH
#   8-901. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a901
#   8-901. load SN191016MC100_P003-a901 Ventricular_Tachycardia True
#   8-902. SN191016MC100_P003-a902 True 0:29:20.011719(450563) *** V-TACH
#   8-902. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a902
#   8-902. load SN191016MC100_P003-a902 Ventricular_Tachycardia True
#   8-903. SN191016MC100_P003-a903 True 0:29:21.601562(450970) *** V-TACH
#   8-903. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a903
#   8-903. load SN191016MC100_P003-a903 Ventricular_Tachycardia True
#   8-904. SN191016MC100_P003-a904 True 0:29:24.863281(451805) *** V-TACH
#   8-904. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a904
#   8-904. load SN191016MC100_P003-a904 Ventricular_Tachycardia True
#   8-905. SN191016MC100_P003-a905 True 0:29:26.285156(452169) *** V-TACH
#   8-905. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a905
#   8-905. load SN191016MC100_P003-a905 Ventricular_Tachycardia True
#   8-906. SN191016MC100_P003-a906 True 0:29:27.699219(452531) *** V-TACH
#   8-906. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a906
#   8-906. load SN191016MC100_P003-a906 Ventricular_Tachycardia True
#   8-907. SN191016MC100_P003-a907 True 0:29:29.089844(452887) *** V-TACH
#   8-907. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a907
#   8-907. load SN191016MC100_P003-a907 Ventricular_Tachycardia True
#   8-908. SN191016MC100_P003-a908 True 0:29:30.750000(453312) *** V-TACH
#   8-908. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a908
#   8-908. load SN191016MC100_P003-a908 Ventricular_Tachycardia True
#   8-909. SN191016MC100_P003-a909 True 0:29:32.113281(453661) *** V-TACH
#   8-909. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a909
#   8-909. load SN191016MC100_P003-a909 Ventricular_Tachycardia True
#   8-910. SN191016MC100_P003-a910 True 0:29:33.437500(454000) *** V-TACH
#   8-910. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a910
#   8-910. load SN191016MC100_P003-a910 Ventricular_Tachycardia True
#   8-911. SN191016MC100_P003-a911 True 0:29:35.824219(454611) *** V-TACH
#   8-911. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a911
#   8-911. load SN191016MC100_P003-a911 Ventricular_Tachycardia True
#   8-912. SN191016MC100_P003-a912 True 0:29:44.488281(456829) *** V-TACH
#   8-912. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a912
#   8-912. load SN191016MC100_P003-a912 Ventricular_Tachycardia True
#   8-913. SN191016MC100_P003-a913 True 0:29:49.429688(458094) *** V-TACH
#   8-913. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a913
#   8-913. load SN191016MC100_P003-a913 Ventricular_Tachycardia True
#   8-914. SN191016MC100_P003-a914 True 0:29:50.785156(458441) *** V-TACH
#   8-914. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a914
#   8-914. load SN191016MC100_P003-a914 Ventricular_Tachycardia True
#   8-915. SN191016MC100_P003-a915 True 0:29:52.347656(458841) *** V-TACH
#   8-915. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a915
#   8-915. load SN191016MC100_P003-a915 Ventricular_Tachycardia True
#   8-916. SN191016MC100_P003-a916 True 0:29:54(459264) *** V-TACH
#   8-916. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a916
#   8-916. load SN191016MC100_P003-a916 Ventricular_Tachycardia True
#   8-917. SN191016MC100_P003-a917 True 0:29:56.378906(459873) *** V-TACH
#   8-917. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a917
#   8-917. load SN191016MC100_P003-a917 Ventricular_Tachycardia True
#   8-918. SN191016MC100_P003-a918 True 0:29:57.019531(460037) *** V-TACH
#   8-918. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a918
#   8-918. load SN191016MC100_P003-a918 Ventricular_Tachycardia True
#   8-919. SN191016MC100_P003-a919 True 0:29:57.699219(460211) *** V-TACH
#   8-919. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a919
#   8-919. load SN191016MC100_P003-a919 Ventricular_Tachycardia True
#   8-920. SN191016MC100_P003-a920 True 0:29:58.378906(460385) *** V-TACH
#   8-920. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a920
#   8-920. load SN191016MC100_P003-a920 Ventricular_Tachycardia True
#   8-921. SN191016MC100_P003-a921 True 0:29:59.875000(460768) *** V-TACH
#   8-921. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a921
#   8-921. load SN191016MC100_P003-a921 Ventricular_Tachycardia True
#   8-922. SN191016MC100_P003-a922 True 0:30:01.355469(461147) *** V-TACH
#   8-922. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a922
#   8-922. load SN191016MC100_P003-a922 Ventricular_Tachycardia True
#   8-923. SN191016MC100_P003-a923 True 0:30:02.687500(461488) *** V-TACH
#   8-923. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a923
#   8-923. load SN191016MC100_P003-a923 Ventricular_Tachycardia True
#   8-924. SN191016MC100_P003-a924 True 0:30:04.363281(461917) *** V-TACH
#   8-924. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a924
#   8-924. load SN191016MC100_P003-a924 Ventricular_Tachycardia True
#   8-925. SN191016MC100_P003-a925 True 0:30:15.828125(464852) *** V-TACH
#   8-925. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a925
#   8-925. load SN191016MC100_P003-a925 Ventricular_Tachycardia True
#   8-926. SN191016MC100_P003-a926 True 0:30:18.863281(465629) *** V-TACH
#   8-926. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a926
#   8-926. load SN191016MC100_P003-a926 Ventricular_Tachycardia True
#   8-927. SN191016MC100_P003-a927 True 0:30:20.050781(465933) *** V-TACH
#   8-927. write /home/nsc/seers/temp/life-threatening_arrhythmias/true/Ventricular_Tachycardia/SN191016MC100_P003-a927
#   8-927. load SN191016MC100_P003-a927 Ventricular_Tachycardia True
# df_mc100 measurement index :  Int64Index([4], dtype='int64')
# df_mc100 make dataset status :  True
# Set True makeDatasetStatus
#
# true Asystole : 0
# false Asystole : 0
#
# true Bradycardia : 0
# false Bradycardia : 0
#
# true Tachycardia : 0
# false Tachycardia : 0
#
# true Ventricular_Tachycardia : 2607
# false Ventricular_Tachycardia : 0
#
# true Ventricular_Flutter_Fib : 241
# false Ventricular_Flutter_Fib : 0
#
# total true : 2848
# total false : 0

# %%
df_mc100['makeDatasetStatus'][df_mc100_measurement_index[0]]
# Out:
# True
