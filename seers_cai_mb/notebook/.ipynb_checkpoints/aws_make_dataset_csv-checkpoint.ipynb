# %%
import os
import sys
import pandas as pd

import logging
import boto3
import io
from io import StringIO # python3; python2: BytesIO 
from botocore.exceptions import ClientError

import shutil

# %%
MODEL_NAME = 'life-threatening_arrhythmias'

BUCKET = 'sndv.analysisdata'
PREFIX = 'dataset/{model_name}/'.format(model_name=MODEL_NAME)

def get_common_prefixes_all(s3_bucket, **base_kwargs):
    continuation_token = None
    while True:
        list_kwargs = dict(MaxKeys=1000, **base_kwargs)
        if continuation_token:
            list_kwargs['ContinuationToken'] = continuation_token
        response = s3_bucket.meta.client.list_objects_v2(**list_kwargs)
        yield from response.get('CommonPrefixes', [])
        if not response.get('IsTruncated'):  # At the end of the list?
            break
        continuation_token = response.get('NextContinuationToken')

# %%
s3 = boto3.resource('s3')
bucket = s3.Bucket(BUCKET)
s3_client = boto3.client('s3')

# %%
df_dataset = pd.DataFrame()
dic_samples = {}
for o in get_common_prefixes_all(bucket, 
                                 Bucket=bucket.name,
                                 Prefix=PREFIX,
                                 Delimiter='/'):
    prefix =o.get('Prefix')
    label = o.get('Prefix').split('/')[-2:][0]
    print('label:', label)
    
    
    dic_arrhythmia = {}
    for o in get_common_prefixes_all(bucket, 
                                     Bucket=bucket.name,
                                     Prefix=prefix,
                                     Delimiter='/'):
        prefix =o.get('Prefix')
        arrhythmia = o.get('Prefix').split('/')[-2:][0]
        print(' arrhythmias:', arrhythmia)
        
        list_dir = []
        list_record = []
        list_alarm_file = []
        list_lead_ii_min = []
        list_lead_ii_max = []
        for o in get_common_prefixes_all(bucket, 
                                         Bucket=bucket.name,
                                         Prefix=prefix,
                                         Delimiter='/'):
            prefix =o.get('Prefix')
            directory = o.get('Prefix').split('/')[-2:][0]
            #print('   directory:', directory)
            object_csv = os.path.join(label, arrhythmia, directory, directory+'.csv')
            list_dir.append(directory)
            list_record.append(directory.split('-a')[0])
            list_alarm_file.append(object_csv)
            
            obj = s3_client.get_object(Bucket=bucket.name, Key=prefix+directory+'.csv')
            df_lead_ii = pd.read_csv(io.BytesIO(obj['Body'].read()),
                                     sep=',', header = None)
            
            df_lead_ii.columns = ['lead_ii']
            list_lead_ii_max.append(df_lead_ii['lead_ii'].max())
            list_lead_ii_min.append(df_lead_ii['lead_ii'].min())

        print ('    directory count : ', len(list_dir))
        df_dataset = df_dataset.append(pd.DataFrame({'record':list_record,
                                                     'alarm_label':label, 
                                                     'arrhythmia':arrhythmia,
                                                     'lead_ii_max':list_lead_ii_max,
                                                     'lead_ii_min':list_lead_ii_min,
                                                     'lead_ii_file':list_alarm_file}))
        dic_arrhythmia[arrhythmia] = list_dir
    dic_samples[label] = dic_arrhythmia
print ("total : ", len(df_dataset))

# %%
df_scatter = df_dataset.sample(frac=1).reset_index(drop=True)
df_sort = df_dataset.sort_values(['record']).reset_index(drop=True)

# %%
csv_buffer = StringIO()
df_sort.to_csv(csv_buffer, index = False)

s3.Object(BUCKET, PREFIX+MODEL_NAME+'.csv').put(Body=csv_buffer.getvalue())

# %%
df_sort
# Out:
#      record alarm_label               arrhythmia  lead_ii_max  lead_ii_min  \
# 0     a103l       false                 Asystole      1.84435     -0.79219
# 1     a104s       false                 Asystole      2.01575     -0.89022
# 2     a105l       false                 Asystole      1.97200     -0.77429
# 3     a109l       false                 Asystole      1.96848     -0.94543
# 4     a134s       false                 Asystole      5.09194     -5.09495
# 5     a142s        true                 Asystole      0.64527     -0.17663
# 6     a145l       false                 Asystole      0.78016     -1.28306
# 7     a161l        true                 Asystole      0.30606     -1.44913
# 8     a163l       false                 Asystole      4.55699     -2.44400
# 9     a165l       false                 Asystole      3.21308     -1.90748
# 10    a167l        true                 Asystole      0.50279     -0.04917
# 11    a170s       false                 Asystole      0.77180     -0.70219
# 12    a171l       false                 Asystole      0.69342     -0.51447
# 13    a172s        true                 Asystole      0.03302     -0.01830
# 14    a178s       false                 Asystole     11.66916     -1.32621
# 15    a185l        true                 Asystole      0.50808     -0.08093
# 16    a186s       false                 Asystole      2.89907     -2.08162
# 17    a203l        true                 Asystole      1.24019     -0.14479
# 18    a219l       false                 Asystole      1.14571     -1.67795
# 19    a223l       false                 Asystole      3.66569     -3.73919
# 20    a225l       false                 Asystole      2.32752     -1.13313
# 21    a226s       false                 Asystole      1.93177     -1.06404
# 22    a239l       false                 Asystole      0.77561     -0.21309
# 23    a266s       false                 Asystole      2.70731     -1.85390
# 24    a267l       false                 Asystole      1.82606     -0.90035
# 25    a272s       false                 Asystole      3.35059     -1.02779
# 26    a273l       false                 Asystole      3.15306     -0.96631
# 27    a278s       false                 Asystole      1.95942     -1.40072
# 28    a287l       false                 Asystole      1.20741      0.04725
# 29    a288s       false                 Asystole      1.23479      0.03096
# ...     ...         ...                      ...          ...          ...
# 6432  v793l        true  Ventricular_Tachycardia      1.01904     -0.28011
# 6433  v795l       false  Ventricular_Tachycardia      1.37618     -0.33500
# 6434  v797l        true  Ventricular_Tachycardia      1.10277     -0.00870
# 6435  v803l        true  Ventricular_Tachycardia      1.39832     -1.74950
# 6436  v804s       false  Ventricular_Tachycardia      1.62219     -0.55942
# 6437  v805l        true  Ventricular_Tachycardia      1.44807     -0.52259
# 6438  v806s        true  Ventricular_Tachycardia      1.50570     -0.53010
# 6439  v808s       false  Ventricular_Tachycardia      1.22838     -0.73275
# 6440  v809l       false  Ventricular_Tachycardia      1.26755     -2.28890
# 6441  v811l       false  Ventricular_Tachycardia      1.51681     -0.56644
# 6442  v813l        true  Ventricular_Tachycardia      1.37037     -0.04727
# 6443  v814s       false  Ventricular_Tachycardia      1.64353     -0.65307
# 6444  v815l        true  Ventricular_Tachycardia      3.20614     -7.28639
# 6445  v818s        true  Ventricular_Tachycardia      1.91516     -0.83031
# 6446  v823l        true  Ventricular_Tachycardia      1.39381     -0.47787
# 6447  v826s       false  Ventricular_Tachycardia      6.51253     -7.79930
# 6448  v827l       false  Ventricular_Tachycardia      1.07863      0.11017
# 6449  v828s        true  Ventricular_Tachycardia      3.42449     -1.55238
# 6450  v830s       false  Ventricular_Tachycardia      1.50400     -0.90350
# 6451  v831l        true  Ventricular_Tachycardia      3.83547     -1.68091
# 6452  v833l       false  Ventricular_Tachycardia      1.79562     -0.60075
# 6453  v834s       false  Ventricular_Tachycardia      2.09536     -1.11793
# 6454  v836s        true  Ventricular_Tachycardia      1.50398     -0.58050
# 6455  v837l        true  Ventricular_Tachycardia      0.85967      0.09036
# 6456  v842s        true  Ventricular_Tachycardia      1.49945     -0.75645
# 6457  v843l       false  Ventricular_Tachycardia      1.55456     -0.54668
# 6458  v844s        true  Ventricular_Tachycardia      1.05177     -0.51839
# 6459  v845l       false  Ventricular_Tachycardia      1.43398     -0.41797
# 6460  v846s       false  Ventricular_Tachycardia      2.14646     -3.21922
# 6461  v848s       false  Ventricular_Tachycardia      0.55049     -0.48721
#
#                                            lead_ii_file
# 0                  false/Asystole/a103l-a1/a103l-a1.csv
# 1                  false/Asystole/a104s-a1/a104s-a1.csv
# 2                  false/Asystole/a105l-a1/a105l-a1.csv
# 3                  false/Asystole/a109l-a1/a109l-a1.csv
# 4                  false/Asystole/a134s-a1/a134s-a1.csv
# 5                   true/Asystole/a142s-a1/a142s-a1.csv
# 6                  false/Asystole/a145l-a1/a145l-a1.csv
# 7                   true/Asystole/a161l-a1/a161l-a1.csv
# 8                  false/Asystole/a163l-a1/a163l-a1.csv
# 9                  false/Asystole/a165l-a1/a165l-a1.csv
# 10                  true/Asystole/a167l-a1/a167l-a1.csv
# 11                 false/Asystole/a170s-a1/a170s-a1.csv
# 12                 false/Asystole/a171l-a1/a171l-a1.csv
# 13                  true/Asystole/a172s-a1/a172s-a1.csv
# 14                 false/Asystole/a178s-a1/a178s-a1.csv
# 15                  true/Asystole/a185l-a1/a185l-a1.csv
# 16                 false/Asystole/a186s-a1/a186s-a1.csv
# 17                  true/Asystole/a203l-a1/a203l-a1.csv
# 18                 false/Asystole/a219l-a1/a219l-a1.csv
# 19                 false/Asystole/a223l-a1/a223l-a1.csv
# 20                 false/Asystole/a225l-a1/a225l-a1.csv
# 21                 false/Asystole/a226s-a1/a226s-a1.csv
# 22                 false/Asystole/a239l-a1/a239l-a1.csv
# 23                 false/Asystole/a266s-a1/a266s-a1.csv
# 24                 false/Asystole/a267l-a1/a267l-a1.csv
# 25                 false/Asystole/a272s-a1/a272s-a1.csv
# 26                 false/Asystole/a273l-a1/a273l-a1.csv
# 27                 false/Asystole/a278s-a1/a278s-a1.csv
# 28                 false/Asystole/a287l-a1/a287l-a1.csv
# 29                 false/Asystole/a288s-a1/a288s-a1.csv
# ...                                                 ...
# 6432  true/Ventricular_Tachycardia/v793l-a1/v793l-a1...
# 6433  false/Ventricular_Tachycardia/v795l-a1/v795l-a...
# 6434  true/Ventricular_Tachycardia/v797l-a1/v797l-a1...
# 6435  true/Ventricular_Tachycardia/v803l-a1/v803l-a1...
# 6436  false/Ventricular_Tachycardia/v804s-a1/v804s-a...
# 6437  true/Ventricular_Tachycardia/v805l-a1/v805l-a1...
# 6438  true/Ventricular_Tachycardia/v806s-a1/v806s-a1...
# 6439  false/Ventricular_Tachycardia/v808s-a1/v808s-a...
# 6440  false/Ventricular_Tachycardia/v809l-a1/v809l-a...
# 6441  false/Ventricular_Tachycardia/v811l-a1/v811l-a...
# 6442  true/Ventricular_Tachycardia/v813l-a1/v813l-a1...
# 6443  false/Ventricular_Tachycardia/v814s-a1/v814s-a...
# 6444  true/Ventricular_Tachycardia/v815l-a1/v815l-a1...
# 6445  true/Ventricular_Tachycardia/v818s-a1/v818s-a1...
# 6446  true/Ventricular_Tachycardia/v823l-a1/v823l-a1...
# 6447  false/Ventricular_Tachycardia/v826s-a1/v826s-a...
# 6448  false/Ventricular_Tachycardia/v827l-a1/v827l-a...
# 6449  true/Ventricular_Tachycardia/v828s-a1/v828s-a1...
# 6450  false/Ventricular_Tachycardia/v830s-a1/v830s-a...
# 6451  true/Ventricular_Tachycardia/v831l-a1/v831l-a1...
# 6452  false/Ventricular_Tachycardia/v833l-a1/v833l-a...
# 6453  false/Ventricular_Tachycardia/v834s-a1/v834s-a...
# 6454  true/Ventricular_Tachycardia/v836s-a1/v836s-a1...
# 6455  true/Ventricular_Tachycardia/v837l-a1/v837l-a1...
# 6456  true/Ventricular_Tachycardia/v842s-a1/v842s-a1...
# 6457  false/Ventricular_Tachycardia/v843l-a1/v843l-a...
# 6458  true/Ventricular_Tachycardia/v844s-a1/v844s-a1...
# 6459  false/Ventricular_Tachycardia/v845l-a1/v845l-a...
# 6460  false/Ventricular_Tachycardia/v846s-a1/v846s-a...
# 6461  false/Ventricular_Tachycardia/v848s-a1/v848s-a...
#
# [6462 rows x 6 columns]
