# %%
# check new data and load

# %%
import numpy as np
import pandas as pd
import shutil
import datetime

import os
import sys
sys.path.append(os.path.dirname(os.path.abspath(''))+'/wfdb-python')
import wfdb
from wfdb import processing
sys.path.append(os.path.dirname(os.path.abspath(''))+'/mc100')
from mc100_class import MC100

# %%
PATH_MC100 = '~temp/mc100/'
MC100_CSV = 'seers_cardio_database_mc100.csv'
MC100_CSV = os.path.join(PATH_MC100, MC100_CSV)

dic_dtype = {'measurementId': 'i',
            'measurementCode': 'S',
            'measurementStatus': 'i',
            'registerUserId': 'i',
            'organizationId': 'i',
            'patientCode': 'S',
            'startDateTime': 'S',
            'endDateTime': 'S',
            'downloadDateTime': 'S',
            'ECGUrl': 'S',
            'fileSize': 'i',
            'sampling': 'i',
            'gain': 'f',
            'endian': 'i',
            'analysisUrl': 'S',
            'storePath': 'S',
            'pridictStatus': 'S',
            'makeDatasetStatus': 'S'}

dic_schema = {'measurementId':np.array([], dtype='i'),
            'measurementCode': np.array([], dtype='S'),
            'measurementStatus': np.array([], dtype='i'),
            'registerUserId': np.array([], dtype='i'),
            'organizationId': np.array([], dtype='i'),
            'patientCode': np.array([], dtype='S'),
            'startDateTime': np.array([], dtype='S'),
            'endDateTime': np.array([], dtype='S'),
            'downloadDateTime': np.array([], dtype='S'),
            'ECGUrl': np.array([], dtype='S'),
            'fileSize': np.array([], dtype='i'),
            'sampling': np.array([], dtype='i'),
            'gain': np.array([], dtype='f'),
            'endian': np.array([], dtype='i'),
            'analysisUrl':np.array([], dtype='S'),
            'storePath': np.array([], dtype='S'),
            'pridictStatus': np.array([], dtype='S'),
            'makeDatasetStatus': np.array([], dtype='S')}

# read db
if os.path.isfile(MC100_CSV):
    df_mc100 = pd.read_csv(MC100_CSV, sep=',', dtype=dic_dtype)
else:
    df_mc100 = pd.DataFrame(dic_schema)

print (df_mc100.dtypes)   
df_mc100
# Out:
# measurementId          int32
# measurementCode       object
# measurementStatus      int32
# registerUserId         int32
# organizationId         int32
# patientCode           object
# startDateTime         object
# endDateTime           object
# downloadDateTime      object
# ECGUrl                object
# fileSize               int32
# sampling               int32
# gain                 float32
# endian                 int32
# analysisUrl           object
# storePath             object
# pridictStatus         object
# makeDatasetStatus     object
# dtype: object
# Empty DataFrame
# Columns: [measurementId, measurementCode, measurementStatus, registerUserId, organizationId, patientCode, startDateTime, endDateTime, downloadDateTime, ECGUrl, fileSize, sampling, gain, endian, analysisUrl, storePath, pridictStatus, makeDatasetStatus]
# Index: []

# %%
# load MC100 raw data

"""
measurementStatus
0x00 : NONE
0x01 : RECODING_START
0x02 : RECODING_END
0x03 : UPLOAD_COMPLETE
0x04 : ANALYZING
0x05 : READY
0x06 : REVIEWING
0x07 : COMPLETED
0x0A : REPORT RELEASE
0x0B : RE ANALYZING
0x0F : ERROR
"""
mc100 = MC100(PATH_MC100)
DOWNLOAD_PATH = mc100.DOWNLOAD_PATH
print ('Load Path : ', DOWNLOAD_PATH)

# get list target load
# mc100.get_list([0x05, 0x06])
mc100.get_list([0x05, 0x06, 0x07]) # for test

for idx, measurement in enumerate(mc100.list_measurement):    
    if measurement['ecgDataList'] is None:        
        continue
    if measurement['analysisOutputFileList'] is None:        
        continue
        
    if df_mc100.loc[df_mc100['measurementId'] == measurement['measurementId']].index.size is not 0 :
        print ('existed measurementId - index:',
               df_mc100.loc[df_mc100['measurementId'] == measurement['measurementId']].index)
        continue
   
    # download ecg, annotation
    print ('download_ecg - ', measurement['measurementCode'])
    mc100.download_ecg([measurement])

    # create record header
    print ('create record header - ', measurement['measurementCode'])
    dt = datetime.datetime.strptime(measurement['ecgDataList'][0]['startDateTime'],'%Y-%m-%d %H:%M:%S')
    path = os.path.join(DOWNLOAD_PATH, measurement['measurementCode'])
    record = wfdb.Record(record_name=measurement['measurementCode'], 
                        n_sig=measurement['ecgDataList'][0]['sequenceNumber'], 
                        fs=measurement['ecgDataList'][0]['sampling'], 
                        sig_len=int(measurement['ecgDataList'][0]['fileSize'] / 2), 
                        base_time=dt.time(), 
                        base_date=dt.date(),
                        file_name=[measurement['ecgDataList'][0]['filename']],
                        fmt=['16'],
                        adc_gain=[measurement['ecgDataList'][0]['gain']],
                        baseline=[0],
                        units=['mV'],
                        adc_res=[16],
                        adc_zero=[0],
                        init_value=[0],
                        checksum =[0],
                        block_size=[0],
                        sig_name=['II'])
    display(record.__dict__)
    record.wrheader(write_dir=path)
           
    # download annotation
    print ('download_annotation - ', measurement['measurementCode'])
    mc100.download_annotation([measurement])

    # create beat annotation file
    record_name = measurement['measurementCode']
    print ('create beat annoation - ', record_name)
    path = os.path.join(DOWNLOAD_PATH, record_name)
    analysis_file = measurement['analysisOutputFileList'][0]['filename']
    print (path, analysis_file)
    
    df = pd.read_csv(os.path.join(path, analysis_file), sep=' ', header=None)
    df.columns = ['second', 'class', 'classNumber', 'beatNumber']
    
    fs = measurement['ecgDataList'][0]['sampling']
    sample = df['second'].to_numpy()
    sample = sample * fs
    sample = sample.astype('i')
    
    symbol = df['class'].tolist()
    aux_note = df['classNumber'].tolist()
    ann = wfdb.Annotation(record_name=record_name, extension='atr',
                          sample=sample, symbol=symbol, aux_note=aux_note, fs=fs)
    ann.wrann(write_fs=True, write_dir=path)
    
    dic_record = {'measurementId':measurement['measurementId'],
                'measurementCode': measurement['measurementCode'],
                'measurementStatus': 0x05, 
                'registerUserId': measurement['registerUserId'], 
                'organizationId': measurement['organizationId'], 
                'patientCode': measurement['patientCode'], 
                'startDateTime': measurement['startDateTime'], 
                'endDateTime': measurement['endDateTime'], 
                'downloadDateTime': datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S'), 
                'ECGUrl': measurement['ecgDataList'][0]['ECGUrl'],
                'fileSize': measurement['ecgDataList'][0]['fileSize'],
                'sampling': measurement['ecgDataList'][0]['sampling'],
                'gain': measurement['ecgDataList'][0]['gain'],
                'endian': measurement['ecgDataList'][0]['endian'],
                'analysisUrl': measurement['analysisOutputFileList'][0]['analysisUrl'],
                'storePath': measurement['storePath'],
                'pridictStatus': False,
                'makeDatasetStatus': False}
    df_mc100 = df_mc100.append(dic_record, ignore_index=True)
    
if len(df_mc100) is not 0:
    df_mc100.to_csv(MC100_CSV, index = False, mode='w')
# Out:
# WAN ip : 14.40.50.110
# LAN ip : 127.0.1.1
# Login - POST request http://13.125.86.65:8080/mobiCARE/cardio/Account/Login
# True 200
# organization_id 8 token 1571663566952RWV9T28M
# Load Path :  /home/nsc/seers/cardio/database/mc100
# get list measure - POST request http://13.125.86.65:8080/mobiCARE/cardio/Measurement/SelectPatientMeasurementInfoByReviewer
# True 200
# count measurement 10
# get list ecg SN191021MC100_P012 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Measurement/SelectECGData
# True 200
# {"result":true,"extra":null,"systemTime":1571663566,"error":0,"message":null,"ecgDataList":null}
#
# get list ecg SN191018MC100_P009 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Measurement/SelectECGData
# True 200
# {"result":true,"extra":null,"systemTime":1571663566,"error":0,"message":null,"ecgDataList":null}
#
# get list ecg SN191018MC100_P007 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Measurement/SelectECGData
# True 200
# count ecg list 1
# {"result":true,"extra":null,"systemTime":1571663566,"error":0,"message":null,"ecgDataList":[{"ecgId":823,"organizationId":8,"measurementCode":"SN191018MC100_P007","key":null,"md5sum":"15f4d2f6b7304fddaa496619b835cd57","sequenceNumber":1,"sampling":256,"gain":100.0,"endian":1,"deviceKind":2,"gmtCode":"GMT+0900","startDateTime":"2019-10-18 13:30:40","endDateTime":"2019-10-18 14:01:39","uploadDateTime":"2019-10-18 14:01:44","modifyDateTime":null,"fileSize":952064}]}
#
# get list ecg SN191018MC100_P006 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Measurement/SelectECGData
# True 200
# count ecg list 1
# {"result":true,"extra":null,"systemTime":1571663566,"error":0,"message":null,"ecgDataList":[{"ecgId":822,"organizationId":8,"measurementCode":"SN191018MC100_P006","key":null,"md5sum":"659a9eddf796aebaf924ee668f5347","sequenceNumber":1,"sampling":256,"gain":100.0,"endian":1,"deviceKind":2,"gmtCode":"GMT+0900","startDateTime":"2019-10-18 12:57:36","endDateTime":"2019-10-18 13:28:11","uploadDateTime":"2019-10-18 13:28:16","modifyDateTime":null,"fileSize":939520}]}
#
# get list ecg SN191016MC100_P005 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Measurement/SelectECGData
# True 200
# count ecg list 1
# {"result":true,"extra":null,"systemTime":1571663566,"error":0,"message":null,"ecgDataList":[{"ecgId":797,"organizationId":8,"measurementCode":"SN191016MC100_P005","key":null,"md5sum":"fae212913292c4f518448412c61992a7","sequenceNumber":1,"sampling":256,"gain":100.0,"endian":1,"deviceKind":2,"gmtCode":"GMT+0900","startDateTime":"2019-10-16 16:24:04","endDateTime":"2019-10-16 16:55:15","uploadDateTime":"2019-10-16 16:55:21","modifyDateTime":null,"fileSize":958464}]}
#
# get list ecg SN191016MC100_P004 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Measurement/SelectECGData
# True 200
# count ecg list 1
# {"result":true,"extra":null,"systemTime":1571663566,"error":0,"message":null,"ecgDataList":[{"ecgId":796,"organizationId":8,"measurementCode":"SN191016MC100_P004","key":null,"md5sum":"bc9c62e9e67797e73783dc8f1c62de4","sequenceNumber":1,"sampling":256,"gain":100.0,"endian":1,"deviceKind":2,"gmtCode":"GMT+0900","startDateTime":"2019-10-16 15:47:10","endDateTime":"2019-10-16 16:20:38","uploadDateTime":"2019-10-16 16:20:49","modifyDateTime":null,"fileSize":1028608}]}
#
# get list ecg SN191016MC100_P003 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Measurement/SelectECGData
# True 200
# count ecg list 1
# {"result":true,"extra":null,"systemTime":1571663566,"error":0,"message":null,"ecgDataList":[{"ecgId":795,"organizationId":8,"measurementCode":"SN191016MC100_P003","key":null,"md5sum":"fb8e5f8f4c331917873bf2f5e6a67430","sequenceNumber":1,"sampling":256,"gain":100.0,"endian":1,"deviceKind":2,"gmtCode":"GMT+0900","startDateTime":"2019-10-16 15:01:22","endDateTime":"2019-10-16 15:32:07","uploadDateTime":"2019-10-16 15:32:12","modifyDateTime":null,"fileSize":944640}]}
#
# get list ecg SN191016MC100_P002 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Measurement/SelectECGData
# True 200
# count ecg list 1
# {"result":true,"extra":null,"systemTime":1571663566,"error":0,"message":null,"ecgDataList":[{"ecgId":786,"organizationId":8,"measurementCode":"SN191016MC100_P002","key":null,"md5sum":"7b4469d884b437e75c71364fadfe7b7","sequenceNumber":1,"sampling":256,"gain":100.0,"endian":1,"deviceKind":2,"gmtCode":"GMT+0900","startDateTime":"2019-10-16 13:55:39","endDateTime":"2019-10-16 14:26:26","uploadDateTime":"2019-10-16 14:26:33","modifyDateTime":null,"fileSize":946176}]}
#
# get list ecg SN191016MC100_P001 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Measurement/SelectECGData
# True 200
# count ecg list 1
# {"result":true,"extra":null,"systemTime":1571663566,"error":0,"message":null,"ecgDataList":[{"ecgId":785,"organizationId":8,"measurementCode":"SN191016MC100_P001","key":null,"md5sum":"c19798ba68c01431ada4735bf7f2458","sequenceNumber":1,"sampling":256,"gain":100.0,"endian":1,"deviceKind":2,"gmtCode":"GMT+0900","startDateTime":"2019-10-16 12:48:53","endDateTime":"2019-10-16 13:33:15","uploadDateTime":"2019-10-16 13:33:22","modifyDateTime":null,"fileSize":1362944}]}
#
# get list ecg NSTest - POST request http://13.125.86.65:8080/mobiCARE/cardio/Measurement/SelectECGData
# True 200
# count ecg list 1
# {"result":true,"extra":null,"systemTime":1571663566,"error":0,"message":null,"ecgDataList":[{"ecgId":203,"organizationId":8,"measurementCode":"NSTest","key":null,"md5sum":"d9e7c1468fdf71aa162b585f28ed84","sequenceNumber":1,"sampling":256,"gain":100.0,"endian":1,"deviceKind":2,"gmtCode":"GMT+0900","startDateTime":"2019-08-30 14:25:05","endDateTime":"2019-08-30 18:44:58","uploadDateTime":"2019-09-02 09:03:48","modifyDateTime":null,"fileSize":7984384}]}
#
# get list annotation SN191021MC100_P012 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Analysis/SelectAnalysisOutputAnnotationFile
# True 200
# {"result":true,"extra":null,"systemTime":1571663567,"error":0,"message":null,"analysisOutputFileList":null}
#
# get list annotation SN191018MC100_P009 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Analysis/SelectAnalysisOutputAnnotationFile
# True 200
# {"result":true,"extra":null,"systemTime":1571663567,"error":0,"message":null,"analysisOutputFileList":null}
#
# get list annotation SN191018MC100_P007 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Analysis/SelectAnalysisOutputAnnotationFile
# True 200
# count annotation list 1
# {"result":true,"extra":null,"systemTime":1571663567,"error":0,"message":null,"analysisOutputFileList":[{"analysisOutputFileId":20374,"organizationId":8,"measurementCode":"SN191018MC100_P007","fileKey":null,"md5sum":"58553ae5f73499468a65e7b8e20226","fileType":7,"reanalyzing":0,"uploadDateTime":"2019-10-18 14:04:14"}]}
#
# get list annotation SN191018MC100_P006 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Analysis/SelectAnalysisOutputAnnotationFile
# True 200
# count annotation list 1
# {"result":true,"extra":null,"systemTime":1571663567,"error":0,"message":null,"analysisOutputFileList":[{"analysisOutputFileId":19758,"organizationId":8,"measurementCode":"SN191018MC100_P006","fileKey":null,"md5sum":"a52c59528c29287bc8932e88d92630","fileType":7,"reanalyzing":0,"uploadDateTime":"2019-10-18 13:28:34"}]}
#
# get list annotation SN191016MC100_P005 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Analysis/SelectAnalysisOutputAnnotationFile
# True 200
# count annotation list 1
# {"result":true,"extra":null,"systemTime":1571663567,"error":0,"message":null,"analysisOutputFileList":[{"analysisOutputFileId":19177,"organizationId":8,"measurementCode":"SN191016MC100_P005","fileKey":null,"md5sum":"8aae22b0dc9671ffb0d810ed24de624f","fileType":7,"reanalyzing":0,"uploadDateTime":"2019-10-16 16:55:52"}]}
#
# get list annotation SN191016MC100_P004 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Analysis/SelectAnalysisOutputAnnotationFile
# True 200
# count annotation list 1
# {"result":true,"extra":null,"systemTime":1571663567,"error":0,"message":null,"analysisOutputFileList":[{"analysisOutputFileId":19163,"organizationId":8,"measurementCode":"SN191016MC100_P004","fileKey":null,"md5sum":"4ad644c0f53395bffab7d94fb586b2e1","fileType":7,"reanalyzing":0,"uploadDateTime":"2019-10-16 16:21:12"}]}
#
# get list annotation SN191016MC100_P003 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Analysis/SelectAnalysisOutputAnnotationFile
# True 200
# count annotation list 1
# {"result":true,"extra":null,"systemTime":1571663567,"error":0,"message":null,"analysisOutputFileList":[{"analysisOutputFileId":19128,"organizationId":8,"measurementCode":"SN191016MC100_P003","fileKey":null,"md5sum":"997abfa65cf827935aaaf702484ad3","fileType":7,"reanalyzing":0,"uploadDateTime":"2019-10-16 15:32:33"}]}
#
# get list annotation SN191016MC100_P002 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Analysis/SelectAnalysisOutputAnnotationFile
# True 200
# count annotation list 1
# {"result":true,"extra":null,"systemTime":1571663567,"error":0,"message":null,"analysisOutputFileList":[{"analysisOutputFileId":18937,"organizationId":8,"measurementCode":"SN191016MC100_P002","fileKey":null,"md5sum":"1bdd83925623118cc2d383366eeef53d","fileType":7,"reanalyzing":0,"uploadDateTime":"2019-10-16 14:27:12"}]}
#
# get list annotation SN191016MC100_P001 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Analysis/SelectAnalysisOutputAnnotationFile
# True 200
# count annotation list 1
# {"result":true,"extra":null,"systemTime":1571663567,"error":0,"message":null,"analysisOutputFileList":[{"analysisOutputFileId":18922,"organizationId":8,"measurementCode":"SN191016MC100_P001","fileKey":null,"md5sum":"40478b5f1e766f44d0ef9a1f83c7f7fd","fileType":7,"reanalyzing":0,"uploadDateTime":"2019-10-16 13:33:54"}]}
#
# get list annotation NSTest - POST request http://13.125.86.65:8080/mobiCARE/cardio/Analysis/SelectAnalysisOutputAnnotationFile
# True 200
# count annotation list 1
# {"result":true,"extra":null,"systemTime":1571663567,"error":0,"message":null,"analysisOutputFileList":[{"analysisOutputFileId":5474,"organizationId":8,"measurementCode":"NSTest","fileKey":null,"md5sum":"2b59dc42c6c9a1072c9817f372398a0","fileType":7,"reanalyzing":0,"uploadDateTime":"2019-09-20 10:20:19"}]}
#
# download_ecg -  SN191018MC100_P007
# SN191018MC100_P007 823
# http://13.125.86.65:8080/mobiCARE/cardio/Measurement/DownloadECGFile/SN191018MC100_P007:823
# form-data; name="attachment"; filename="SN191018MC100_P007_01_20191018_140144.ecg"
# filename :  SN191018MC100_P007_01_20191018_140144.ecg
# create record header -  SN191018MC100_P007
# {'record_name': 'SN191018MC100_P007',
#  'n_sig': 1,
#  'fs': 256,
#  'counter_freq': None,
#  'base_counter': None,
#  'sig_len': 476032,
#  'base_time': datetime.time(13, 30, 40),
#  'base_date': datetime.date(2019, 10, 18),
#  'comments': None,
#  'sig_name': ['II'],
#  'p_signal': None,
#  'd_signal': None,
#  'e_p_signal': None,
#  'e_d_signal': None,
#  'file_name': ['SN191018MC100_P007_01_20191018_140144.ecg'],
#  'fmt': ['16'],
#  'samps_per_frame': None,
#  'skew': None,
#  'byte_offset': None,
#  'adc_gain': [100.0],
#  'baseline': [0],
#  'units': ['mV'],
#  'adc_res': [16],
#  'adc_zero': [0],
#  'init_value': [0],
#  'checksum': [0],
#  'block_size': [0]}
# download_annotation -  SN191018MC100_P007
# SN191018MC100_P007 20374
# http://13.125.86.65:8080/mobiCARE/cardio/Analysis/DownloadAnalysisOutputFile/SN191018MC100_P007:20374
# form-data; name="attachment"; filename="hbclass.txt"
# filename :  hbclass.txt
# create beat annoation -  SN191018MC100_P007
# /home/nsc/seers/cardio/database/mc100/SN191018MC100_P007 hbclass.txt
# download_ecg -  SN191018MC100_P006
# SN191018MC100_P006 822
# http://13.125.86.65:8080/mobiCARE/cardio/Measurement/DownloadECGFile/SN191018MC100_P006:822
# form-data; name="attachment"; filename="SN191018MC100_P006_01_20191018_132816.ecg"
# filename :  SN191018MC100_P006_01_20191018_132816.ecg
# create record header -  SN191018MC100_P006
# {'record_name': 'SN191018MC100_P006',
#  'n_sig': 1,
#  'fs': 256,
#  'counter_freq': None,
#  'base_counter': None,
#  'sig_len': 469760,
#  'base_time': datetime.time(12, 57, 36),
#  'base_date': datetime.date(2019, 10, 18),
#  'comments': None,
#  'sig_name': ['II'],
#  'p_signal': None,
#  'd_signal': None,
#  'e_p_signal': None,
#  'e_d_signal': None,
#  'file_name': ['SN191018MC100_P006_01_20191018_132816.ecg'],
#  'fmt': ['16'],
#  'samps_per_frame': None,
#  'skew': None,
#  'byte_offset': None,
#  'adc_gain': [100.0],
#  'baseline': [0],
#  'units': ['mV'],
#  'adc_res': [16],
#  'adc_zero': [0],
#  'init_value': [0],
#  'checksum': [0],
#  'block_size': [0]}
# download_annotation -  SN191018MC100_P006
# SN191018MC100_P006 19758
# http://13.125.86.65:8080/mobiCARE/cardio/Analysis/DownloadAnalysisOutputFile/SN191018MC100_P006:19758
# form-data; name="attachment"; filename="hbclass.txt"
# filename :  hbclass.txt
# create beat annoation -  SN191018MC100_P006
# /home/nsc/seers/cardio/database/mc100/SN191018MC100_P006 hbclass.txt
# download_ecg -  SN191016MC100_P005
# SN191016MC100_P005 797
# http://13.125.86.65:8080/mobiCARE/cardio/Measurement/DownloadECGFile/SN191016MC100_P005:797
# form-data; name="attachment"; filename="SN191016MC100_P005_01_20191016_165521.ecg"
# filename :  SN191016MC100_P005_01_20191016_165521.ecg
# create record header -  SN191016MC100_P005
# {'record_name': 'SN191016MC100_P005',
#  'n_sig': 1,
#  'fs': 256,
#  'counter_freq': None,
#  'base_counter': None,
#  'sig_len': 479232,
#  'base_time': datetime.time(16, 24, 4),
#  'base_date': datetime.date(2019, 10, 16),
#  'comments': None,
#  'sig_name': ['II'],
#  'p_signal': None,
#  'd_signal': None,
#  'e_p_signal': None,
#  'e_d_signal': None,
#  'file_name': ['SN191016MC100_P005_01_20191016_165521.ecg'],
#  'fmt': ['16'],
#  'samps_per_frame': None,
#  'skew': None,
#  'byte_offset': None,
#  'adc_gain': [100.0],
#  'baseline': [0],
#  'units': ['mV'],
#  'adc_res': [16],
#  'adc_zero': [0],
#  'init_value': [0],
#  'checksum': [0],
#  'block_size': [0]}
# download_annotation -  SN191016MC100_P005
# SN191016MC100_P005 19177
# http://13.125.86.65:8080/mobiCARE/cardio/Analysis/DownloadAnalysisOutputFile/SN191016MC100_P005:19177
# form-data; name="attachment"; filename="hbclass.txt"
# filename :  hbclass.txt
# create beat annoation -  SN191016MC100_P005
# /home/nsc/seers/cardio/database/mc100/SN191016MC100_P005 hbclass.txt
# download_ecg -  SN191016MC100_P004
# SN191016MC100_P004 796
# http://13.125.86.65:8080/mobiCARE/cardio/Measurement/DownloadECGFile/SN191016MC100_P004:796
# form-data; name="attachment"; filename="SN191016MC100_P004_01_20191016_162049.ecg"
# filename :  SN191016MC100_P004_01_20191016_162049.ecg
# create record header -  SN191016MC100_P004
# {'record_name': 'SN191016MC100_P004',
#  'n_sig': 1,
#  'fs': 256,
#  'counter_freq': None,
#  'base_counter': None,
#  'sig_len': 514304,
#  'base_time': datetime.time(15, 47, 10),
#  'base_date': datetime.date(2019, 10, 16),
#  'comments': None,
#  'sig_name': ['II'],
#  'p_signal': None,
#  'd_signal': None,
#  'e_p_signal': None,
#  'e_d_signal': None,
#  'file_name': ['SN191016MC100_P004_01_20191016_162049.ecg'],
#  'fmt': ['16'],
#  'samps_per_frame': None,
#  'skew': None,
#  'byte_offset': None,
#  'adc_gain': [100.0],
#  'baseline': [0],
#  'units': ['mV'],
#  'adc_res': [16],
#  'adc_zero': [0],
#  'init_value': [0],
#  'checksum': [0],
#  'block_size': [0]}
# download_annotation -  SN191016MC100_P004
# SN191016MC100_P004 19163
# http://13.125.86.65:8080/mobiCARE/cardio/Analysis/DownloadAnalysisOutputFile/SN191016MC100_P004:19163
# form-data; name="attachment"; filename="hbclass.txt"
# filename :  hbclass.txt
# create beat annoation -  SN191016MC100_P004
# /home/nsc/seers/cardio/database/mc100/SN191016MC100_P004 hbclass.txt
# download_ecg -  SN191016MC100_P003
# SN191016MC100_P003 795
# http://13.125.86.65:8080/mobiCARE/cardio/Measurement/DownloadECGFile/SN191016MC100_P003:795
# form-data; name="attachment"; filename="SN191016MC100_P003_01_20191016_153212.ecg"
# filename :  SN191016MC100_P003_01_20191016_153212.ecg
# create record header -  SN191016MC100_P003
# {'record_name': 'SN191016MC100_P003',
#  'n_sig': 1,
#  'fs': 256,
#  'counter_freq': None,
#  'base_counter': None,
#  'sig_len': 472320,
#  'base_time': datetime.time(15, 1, 22),
#  'base_date': datetime.date(2019, 10, 16),
#  'comments': None,
#  'sig_name': ['II'],
#  'p_signal': None,
#  'd_signal': None,
#  'e_p_signal': None,
#  'e_d_signal': None,
#  'file_name': ['SN191016MC100_P003_01_20191016_153212.ecg'],
#  'fmt': ['16'],
#  'samps_per_frame': None,
#  'skew': None,
#  'byte_offset': None,
#  'adc_gain': [100.0],
#  'baseline': [0],
#  'units': ['mV'],
#  'adc_res': [16],
#  'adc_zero': [0],
#  'init_value': [0],
#  'checksum': [0],
#  'block_size': [0]}
# download_annotation -  SN191016MC100_P003
# SN191016MC100_P003 19128
# http://13.125.86.65:8080/mobiCARE/cardio/Analysis/DownloadAnalysisOutputFile/SN191016MC100_P003:19128
# form-data; name="attachment"; filename="hbclass.txt"
# filename :  hbclass.txt
# create beat annoation -  SN191016MC100_P003
# /home/nsc/seers/cardio/database/mc100/SN191016MC100_P003 hbclass.txt
# download_ecg -  SN191016MC100_P002
# SN191016MC100_P002 786
# http://13.125.86.65:8080/mobiCARE/cardio/Measurement/DownloadECGFile/SN191016MC100_P002:786
# form-data; name="attachment"; filename="SN191016MC100_P002_01_20191016_142633.ecg"
# filename :  SN191016MC100_P002_01_20191016_142633.ecg
# create record header -  SN191016MC100_P002
# {'record_name': 'SN191016MC100_P002',
#  'n_sig': 1,
#  'fs': 256,
#  'counter_freq': None,
#  'base_counter': None,
#  'sig_len': 473088,
#  'base_time': datetime.time(13, 55, 39),
#  'base_date': datetime.date(2019, 10, 16),
#  'comments': None,
#  'sig_name': ['II'],
#  'p_signal': None,
#  'd_signal': None,
#  'e_p_signal': None,
#  'e_d_signal': None,
#  'file_name': ['SN191016MC100_P002_01_20191016_142633.ecg'],
#  'fmt': ['16'],
#  'samps_per_frame': None,
#  'skew': None,
#  'byte_offset': None,
#  'adc_gain': [100.0],
#  'baseline': [0],
#  'units': ['mV'],
#  'adc_res': [16],
#  'adc_zero': [0],
#  'init_value': [0],
#  'checksum': [0],
#  'block_size': [0]}
# download_annotation -  SN191016MC100_P002
# SN191016MC100_P002 18937
# http://13.125.86.65:8080/mobiCARE/cardio/Analysis/DownloadAnalysisOutputFile/SN191016MC100_P002:18937
# form-data; name="attachment"; filename="hbclass.txt"
# filename :  hbclass.txt
# create beat annoation -  SN191016MC100_P002
# /home/nsc/seers/cardio/database/mc100/SN191016MC100_P002 hbclass.txt
# download_ecg -  SN191016MC100_P001
# SN191016MC100_P001 785
# http://13.125.86.65:8080/mobiCARE/cardio/Measurement/DownloadECGFile/SN191016MC100_P001:785
# form-data; name="attachment"; filename="SN191016MC100_P001_01_20191016_133322.ecg"
# filename :  SN191016MC100_P001_01_20191016_133322.ecg
# create record header -  SN191016MC100_P001
# {'record_name': 'SN191016MC100_P001',
#  'n_sig': 1,
#  'fs': 256,
#  'counter_freq': None,
#  'base_counter': None,
#  'sig_len': 681472,
#  'base_time': datetime.time(12, 48, 53),
#  'base_date': datetime.date(2019, 10, 16),
#  'comments': None,
#  'sig_name': ['II'],
#  'p_signal': None,
#  'd_signal': None,
#  'e_p_signal': None,
#  'e_d_signal': None,
#  'file_name': ['SN191016MC100_P001_01_20191016_133322.ecg'],
#  'fmt': ['16'],
#  'samps_per_frame': None,
#  'skew': None,
#  'byte_offset': None,
#  'adc_gain': [100.0],
#  'baseline': [0],
#  'units': ['mV'],
#  'adc_res': [16],
#  'adc_zero': [0],
#  'init_value': [0],
#  'checksum': [0],
#  'block_size': [0]}
# download_annotation -  SN191016MC100_P001
# SN191016MC100_P001 18922
# http://13.125.86.65:8080/mobiCARE/cardio/Analysis/DownloadAnalysisOutputFile/SN191016MC100_P001:18922
# form-data; name="attachment"; filename="hbclass.txt"
# filename :  hbclass.txt
# create beat annoation -  SN191016MC100_P001
# /home/nsc/seers/cardio/database/mc100/SN191016MC100_P001 hbclass.txt
# download_ecg -  NSTest
# NSTest 203
# http://13.125.86.65:8080/mobiCARE/cardio/Measurement/DownloadECGFile/NSTest:203
# form-data; name="attachment"; filename="NSTest_01_20190830_142505.ecg"
# filename :  NSTest_01_20190830_142505.ecg
# create record header -  NSTest
# {'record_name': 'NSTest',
#  'n_sig': 1,
#  'fs': 256,
#  'counter_freq': None,
#  'base_counter': None,
#  'sig_len': 3992192,
#  'base_time': datetime.time(14, 25, 5),
#  'base_date': datetime.date(2019, 8, 30),
#  'comments': None,
#  'sig_name': ['II'],
#  'p_signal': None,
#  'd_signal': None,
#  'e_p_signal': None,
#  'e_d_signal': None,
#  'file_name': ['NSTest_01_20190830_142505.ecg'],
#  'fmt': ['16'],
#  'samps_per_frame': None,
#  'skew': None,
#  'byte_offset': None,
#  'adc_gain': [100.0],
#  'baseline': [0],
#  'units': ['mV'],
#  'adc_res': [16],
#  'adc_zero': [0],
#  'init_value': [0],
#  'checksum': [0],
#  'block_size': [0]}
# download_annotation -  NSTest
# NSTest 5474
# http://13.125.86.65:8080/mobiCARE/cardio/Analysis/DownloadAnalysisOutputFile/NSTest:5474
# form-data; name="attachment"; filename="hbclass.txt"
# filename :  hbclass.txt
# create beat annoation -  NSTest
# /home/nsc/seers/cardio/database/mc100/NSTest hbclass.txt

# %%
mc100.list_measurement
# Out:
# [{'measurementId': 364,
#   'measurementCode': 'SN191021MC100_P012',
#   'registerUserId': 21,
#   'reviewerUserId': 21,
#   'deviceCode': '29415',
#   'organizationId': 8,
#   'patientCode': None,
#   'diseaseCode': None,
#   'firstName': 'Robert',
#   'lastName': 'Kim',
#   'gender': 1,
#   'birthday': None,
#   'height': 0.0,
#   'weight': 0.0,
#   'phoneNumber': None,
#   'measurementStatus': 6,
#   'shard': '2019',
#   'part': 29,
#   'reanalyzing': 0,
#   'deviceKind': 3,
#   'duration': 0,
#   'elapsedTime': 93556,
#   'gmtCode': 'GMT+0900',
#   'timezone': 'Asia/Seoul',
#   'countryCode': 'KR',
#   'dateTime': '2019-10-21 10:44:46',
#   'startDateTime': '2019-10-21 10:44:41',
#   'endDateTime': '2019-10-22 12:43:57',
#   'modifyDateTime': '2019-10-21 12:47:50',
#   'etc': None,
#   'ecgDataList': None,
#   'analysisOutputFileList': None},
#  {'measurementId': 352,
#   'measurementCode': 'SN191018MC100_P009',
#   'registerUserId': 21,
#   'reviewerUserId': 21,
#   'deviceCode': '29415',
#   'organizationId': 8,
#   'patientCode': None,
#   'diseaseCode': None,
#   'firstName': 'Robert',
#   'lastName': 'Park',
#   'gender': 1,
#   'birthday': None,
#   'height': 0.0,
#   'weight': 0.0,
#   'phoneNumber': None,
#   'measurementStatus': 7,
#   'shard': '2019',
#   'part': 19,
#   'reanalyzing': 0,
#   'deviceKind': 3,
#   'duration': 0,
#   'elapsedTime': 93600,
#   'gmtCode': 'GMT+0900',
#   'timezone': 'Asia/Seoul',
#   'countryCode': 'KR',
#   'dateTime': '2019-10-18 15:19:28',
#   'startDateTime': '2019-10-18 15:18:43',
#   'endDateTime': '2019-10-19 17:18:43',
#   'modifyDateTime': '2019-10-18 15:20:56',
#   'etc': None,
#   'ecgDataList': None,
#   'analysisOutputFileList': None},
#  {'measurementId': 349,
#   'measurementCode': 'SN191018MC100_P007',
#   'registerUserId': 21,
#   'reviewerUserId': 21,
#   'deviceCode': '29415',
#   'organizationId': 8,
#   'patientCode': None,
#   'diseaseCode': None,
#   'firstName': 'Alice',
#   'lastName': 'Kim',
#   'gender': 2,
#   'birthday': None,
#   'height': 0.0,
#   'weight': 0.0,
#   'phoneNumber': None,
#   'measurementStatus': 7,
#   'shard': '2019',
#   'part': 16,
#   'reanalyzing': 0,
#   'deviceKind': 3,
#   'duration': 0,
#   'elapsedTime': 1859,
#   'gmtCode': 'GMT+0900',
#   'timezone': 'Asia/Seoul',
#   'countryCode': 'KR',
#   'dateTime': '2019-10-18 13:29:07',
#   'startDateTime': '2019-10-18 13:30:40',
#   'endDateTime': '2019-10-18 14:01:39',
#   'modifyDateTime': '2019-10-18 15:09:32',
#   'etc': None,
#   'ecgDataList': [{'ecgId': 823,
#     'organizationId': 8,
#     'measurementCode': 'SN191018MC100_P007',
#     'key': None,
#     'md5sum': '15f4d2f6b7304fddaa496619b835cd57',
#     'sequenceNumber': 1,
#     'sampling': 256,
#     'gain': 100.0,
#     'endian': 1,
#     'deviceKind': 2,
#     'gmtCode': 'GMT+0900',
#     'startDateTime': '2019-10-18 13:30:40',
#     'endDateTime': '2019-10-18 14:01:39',
#     'uploadDateTime': '2019-10-18 14:01:44',
#     'modifyDateTime': None,
#     'fileSize': 952064,
#     'ECGUrl': 'http://13.125.86.65:8080/mobiCARE/cardio/Measurement/DownloadECGFile/SN191018MC100_P007:823',
#     'filename': 'SN191018MC100_P007_01_20191018_140144.ecg'}],
#   'analysisOutputFileList': [{'analysisOutputFileId': 20374,
#     'organizationId': 8,
#     'measurementCode': 'SN191018MC100_P007',
#     'fileKey': None,
#     'md5sum': '58553ae5f73499468a65e7b8e20226',
#     'fileType': 7,
#     'reanalyzing': 0,
#     'uploadDateTime': '2019-10-18 14:04:14',
#     'analysisUrl': 'http://13.125.86.65:8080/mobiCARE/cardio/Analysis/DownloadAnalysisOutputFile/SN191018MC100_P007:20374',
#     'filename': 'hbclass.txt'}],
#   'storePath': '/home/nsc/seers/cardio/database/mc100/SN191018MC100_P007'},
#  {'measurementId': 346,
#   'measurementCode': 'SN191018MC100_P006',
#   'registerUserId': 21,
#   'reviewerUserId': 21,
#   'deviceCode': '29415',
#   'organizationId': 8,
#   'patientCode': None,
#   'diseaseCode': None,
#   'firstName': 'Alice ',
#   'lastName': 'Kim',
#   'gender': 2,
#   'birthday': None,
#   'height': 0.0,
#   'weight': 0.0,
#   'phoneNumber': None,
#   'measurementStatus': 7,
#   'shard': '2019',
#   'part': 13,
#   'reanalyzing': 0,
#   'deviceKind': 3,
#   'duration': 0,
#   'elapsedTime': 1835,
#   'gmtCode': 'GMT+0900',
#   'timezone': 'Asia/Seoul',
#   'countryCode': 'KR',
#   'dateTime': '2019-10-18 12:56:42',
#   'startDateTime': '2019-10-18 12:57:36',
#   'endDateTime': '2019-10-18 13:28:11',
#   'modifyDateTime': '2019-10-18 13:32:00',
#   'etc': None,
#   'ecgDataList': [{'ecgId': 822,
#     'organizationId': 8,
#     'measurementCode': 'SN191018MC100_P006',
#     'key': None,
#     'md5sum': '659a9eddf796aebaf924ee668f5347',
#     'sequenceNumber': 1,
#     'sampling': 256,
#     'gain': 100.0,
#     'endian': 1,
#     'deviceKind': 2,
#     'gmtCode': 'GMT+0900',
#     'startDateTime': '2019-10-18 12:57:36',
#     'endDateTime': '2019-10-18 13:28:11',
#     'uploadDateTime': '2019-10-18 13:28:16',
#     'modifyDateTime': None,
#     'fileSize': 939520,
#     'ECGUrl': 'http://13.125.86.65:8080/mobiCARE/cardio/Measurement/DownloadECGFile/SN191018MC100_P006:822',
#     'filename': 'SN191018MC100_P006_01_20191018_132816.ecg'}],
#   'analysisOutputFileList': [{'analysisOutputFileId': 19758,
#     'organizationId': 8,
#     'measurementCode': 'SN191018MC100_P006',
#     'fileKey': None,
#     'md5sum': 'a52c59528c29287bc8932e88d92630',
#     'fileType': 7,
#     'reanalyzing': 0,
#     'uploadDateTime': '2019-10-18 13:28:34',
#     'analysisUrl': 'http://13.125.86.65:8080/mobiCARE/cardio/Analysis/DownloadAnalysisOutputFile/SN191018MC100_P006:19758',
#     'filename': 'hbclass.txt'}],
#   'storePath': '/home/nsc/seers/cardio/database/mc100/SN191018MC100_P006'},
#  {'measurementId': 337,
#   'measurementCode': 'SN191016MC100_P005',
#   'registerUserId': 21,
#   'reviewerUserId': 21,
#   'deviceCode': '29415',
#   'organizationId': 8,
#   'patientCode': None,
#   'diseaseCode': None,
#   'firstName': 'Alice ',
#   'lastName': 'Kim',
#   'gender': 2,
#   'birthday': None,
#   'height': 0.0,
#   'weight': 0.0,
#   'phoneNumber': None,
#   'measurementStatus': 7,
#   'shard': '2019',
#   'part': 4,
#   'reanalyzing': 0,
#   'deviceKind': 3,
#   'duration': 0,
#   'elapsedTime': 1871,
#   'gmtCode': 'GMT+0900',
#   'timezone': 'Asia/Seoul',
#   'countryCode': 'KR',
#   'dateTime': '2019-10-16 16:23:28',
#   'startDateTime': '2019-10-16 16:24:04',
#   'endDateTime': '2019-10-16 16:55:15',
#   'modifyDateTime': '2019-10-16 17:05:50',
#   'etc': None,
#   'ecgDataList': [{'ecgId': 797,
#     'organizationId': 8,
#     'measurementCode': 'SN191016MC100_P005',
#     'key': None,
#     'md5sum': 'fae212913292c4f518448412c61992a7',
#     'sequenceNumber': 1,
#     'sampling': 256,
#     'gain': 100.0,
#     'endian': 1,
#     'deviceKind': 2,
#     'gmtCode': 'GMT+0900',
#     'startDateTime': '2019-10-16 16:24:04',
#     'endDateTime': '2019-10-16 16:55:15',
#     'uploadDateTime': '2019-10-16 16:55:21',
#     'modifyDateTime': None,
#     'fileSize': 958464,
#     'ECGUrl': 'http://13.125.86.65:8080/mobiCARE/cardio/Measurement/DownloadECGFile/SN191016MC100_P005:797',
#     'filename': 'SN191016MC100_P005_01_20191016_165521.ecg'}],
#   'analysisOutputFileList': [{'analysisOutputFileId': 19177,
#     'organizationId': 8,
#     'measurementCode': 'SN191016MC100_P005',
#     'fileKey': None,
#     'md5sum': '8aae22b0dc9671ffb0d810ed24de624f',
#     'fileType': 7,
#     'reanalyzing': 0,
#     'uploadDateTime': '2019-10-16 16:55:52',
#     'analysisUrl': 'http://13.125.86.65:8080/mobiCARE/cardio/Analysis/DownloadAnalysisOutputFile/SN191016MC100_P005:19177',
#     'filename': 'hbclass.txt'}],
#   'storePath': '/home/nsc/seers/cardio/database/mc100/SN191016MC100_P005'},
#  {'measurementId': 336,
#   'measurementCode': 'SN191016MC100_P004',
#   'registerUserId': 21,
#   'reviewerUserId': 21,
#   'deviceCode': '29415',
#   'organizationId': 8,
#   'patientCode': None,
#   'diseaseCode': None,
#   'firstName': 'Alice',
#   'lastName': 'Kim',
#   'gender': 2,
#   'birthday': None,
#   'height': 0.0,
#   'weight': 0.0,
#   'phoneNumber': None,
#   'measurementStatus': 7,
#   'shard': '2019',
#   'part': 3,
#   'reanalyzing': 0,
#   'deviceKind': 3,
#   'duration': 0,
#   'elapsedTime': 2008,
#   'gmtCode': 'GMT+0900',
#   'timezone': 'Asia/Seoul',
#   'countryCode': 'KR',
#   'dateTime': '2019-10-16 15:46:35',
#   'startDateTime': '2019-10-16 15:47:10',
#   'endDateTime': '2019-10-16 16:20:38',
#   'modifyDateTime': '2019-10-16 16:22:11',
#   'etc': None,
#   'ecgDataList': [{'ecgId': 796,
#     'organizationId': 8,
#     'measurementCode': 'SN191016MC100_P004',
#     'key': None,
#     'md5sum': 'bc9c62e9e67797e73783dc8f1c62de4',
#     'sequenceNumber': 1,
#     'sampling': 256,
#     'gain': 100.0,
#     'endian': 1,
#     'deviceKind': 2,
#     'gmtCode': 'GMT+0900',
#     'startDateTime': '2019-10-16 15:47:10',
#     'endDateTime': '2019-10-16 16:20:38',
#     'uploadDateTime': '2019-10-16 16:20:49',
#     'modifyDateTime': None,
#     'fileSize': 1028608,
#     'ECGUrl': 'http://13.125.86.65:8080/mobiCARE/cardio/Measurement/DownloadECGFile/SN191016MC100_P004:796',
#     'filename': 'SN191016MC100_P004_01_20191016_162049.ecg'}],
#   'analysisOutputFileList': [{'analysisOutputFileId': 19163,
#     'organizationId': 8,
#     'measurementCode': 'SN191016MC100_P004',
#     'fileKey': None,
#     'md5sum': '4ad644c0f53395bffab7d94fb586b2e1',
#     'fileType': 7,
#     'reanalyzing': 0,
#     'uploadDateTime': '2019-10-16 16:21:12',
#     'analysisUrl': 'http://13.125.86.65:8080/mobiCARE/cardio/Analysis/DownloadAnalysisOutputFile/SN191016MC100_P004:19163',
#     'filename': 'hbclass.txt'}],
#   'storePath': '/home/nsc/seers/cardio/database/mc100/SN191016MC100_P004'},
#  {'measurementId': 335,
#   'measurementCode': 'SN191016MC100_P003',
#   'registerUserId': 21,
#   'reviewerUserId': 21,
#   'deviceCode': '29415',
#   'organizationId': 8,
#   'patientCode': None,
#   'diseaseCode': None,
#   'firstName': 'Alice',
#   'lastName': 'Kim',
#   'gender': 2,
#   'birthday': None,
#   'height': 0.0,
#   'weight': 0.0,
#   'phoneNumber': None,
#   'measurementStatus': 7,
#   'shard': '2019',
#   'part': 2,
#   'reanalyzing': 0,
#   'deviceKind': 3,
#   'duration': 0,
#   'elapsedTime': 1845,
#   'gmtCode': 'GMT+0900',
#   'timezone': 'Asia/Seoul',
#   'countryCode': 'KR',
#   'dateTime': '2019-10-16 15:00:52',
#   'startDateTime': '2019-10-16 15:01:22',
#   'endDateTime': '2019-10-16 15:32:07',
#   'modifyDateTime': '2019-10-16 15:44:44',
#   'etc': None,
#   'ecgDataList': [{'ecgId': 795,
#     'organizationId': 8,
#     'measurementCode': 'SN191016MC100_P003',
#     'key': None,
#     'md5sum': 'fb8e5f8f4c331917873bf2f5e6a67430',
#     'sequenceNumber': 1,
#     'sampling': 256,
#     'gain': 100.0,
#     'endian': 1,
#     'deviceKind': 2,
#     'gmtCode': 'GMT+0900',
#     'startDateTime': '2019-10-16 15:01:22',
#     'endDateTime': '2019-10-16 15:32:07',
#     'uploadDateTime': '2019-10-16 15:32:12',
#     'modifyDateTime': None,
#     'fileSize': 944640,
#     'ECGUrl': 'http://13.125.86.65:8080/mobiCARE/cardio/Measurement/DownloadECGFile/SN191016MC100_P003:795',
#     'filename': 'SN191016MC100_P003_01_20191016_153212.ecg'}],
#   'analysisOutputFileList': [{'analysisOutputFileId': 19128,
#     'organizationId': 8,
#     'measurementCode': 'SN191016MC100_P003',
#     'fileKey': None,
#     'md5sum': '997abfa65cf827935aaaf702484ad3',
#     'fileType': 7,
#     'reanalyzing': 0,
#     'uploadDateTime': '2019-10-16 15:32:33',
#     'analysisUrl': 'http://13.125.86.65:8080/mobiCARE/cardio/Analysis/DownloadAnalysisOutputFile/SN191016MC100_P003:19128',
#     'filename': 'hbclass.txt'}],
#   'storePath': '/home/nsc/seers/cardio/database/mc100/SN191016MC100_P003'},
#  {'measurementId': 329,
#   'measurementCode': 'SN191016MC100_P002',
#   'registerUserId': 21,
#   'reviewerUserId': 21,
#   'deviceCode': '29415',
#   'organizationId': 8,
#   'patientCode': None,
#   'diseaseCode': None,
#   'firstName': 'Alice',
#   'lastName': 'Kim',
#   'gender': 2,
#   'birthday': None,
#   'height': 0.0,
#   'weight': 0.0,
#   'phoneNumber': None,
#   'measurementStatus': 7,
#   'shard': '2019',
#   'part': 46,
#   'reanalyzing': 0,
#   'deviceKind': 3,
#   'duration': 0,
#   'elapsedTime': 1847,
#   'gmtCode': 'GMT+0900',
#   'timezone': 'Asia/Seoul',
#   'countryCode': 'KR',
#   'dateTime': '2019-10-16 13:44:02',
#   'startDateTime': '2019-10-16 13:55:39',
#   'endDateTime': '2019-10-16 14:26:26',
#   'modifyDateTime': '2019-10-16 14:30:04',
#   'etc': None,
#   'ecgDataList': [{'ecgId': 786,
#     'organizationId': 8,
#     'measurementCode': 'SN191016MC100_P002',
#     'key': None,
#     'md5sum': '7b4469d884b437e75c71364fadfe7b7',
#     'sequenceNumber': 1,
#     'sampling': 256,
#     'gain': 100.0,
#     'endian': 1,
#     'deviceKind': 2,
#     'gmtCode': 'GMT+0900',
#     'startDateTime': '2019-10-16 13:55:39',
#     'endDateTime': '2019-10-16 14:26:26',
#     'uploadDateTime': '2019-10-16 14:26:33',
#     'modifyDateTime': None,
#     'fileSize': 946176,
#     'ECGUrl': 'http://13.125.86.65:8080/mobiCARE/cardio/Measurement/DownloadECGFile/SN191016MC100_P002:786',
#     'filename': 'SN191016MC100_P002_01_20191016_142633.ecg'}],
#   'analysisOutputFileList': [{'analysisOutputFileId': 18937,
#     'organizationId': 8,
#     'measurementCode': 'SN191016MC100_P002',
#     'fileKey': None,
#     'md5sum': '1bdd83925623118cc2d383366eeef53d',
#     'fileType': 7,
#     'reanalyzing': 0,
#     'uploadDateTime': '2019-10-16 14:27:12',
#     'analysisUrl': 'http://13.125.86.65:8080/mobiCARE/cardio/Analysis/DownloadAnalysisOutputFile/SN191016MC100_P002:18937',
#     'filename': 'hbclass.txt'}],
#   'storePath': '/home/nsc/seers/cardio/database/mc100/SN191016MC100_P002'},
#  {'measurementId': 327,
#   'measurementCode': 'SN191016MC100_P001',
#   'registerUserId': 21,
#   'reviewerUserId': 21,
#   'deviceCode': '29415',
#   'organizationId': 8,
#   'patientCode': None,
#   'diseaseCode': None,
#   'firstName': 'Alice',
#   'lastName': 'Kim',
#   'gender': 2,
#   'birthday': None,
#   'height': 0.0,
#   'weight': 0.0,
#   'phoneNumber': None,
#   'measurementStatus': 7,
#   'shard': '2019',
#   'part': 44,
#   'reanalyzing': 0,
#   'deviceKind': 3,
#   'duration': 0,
#   'elapsedTime': 2662,
#   'gmtCode': 'GMT+0900',
#   'timezone': 'Asia/Seoul',
#   'countryCode': 'KR',
#   'dateTime': '2019-10-16 12:46:57',
#   'startDateTime': '2019-10-16 12:48:53',
#   'endDateTime': '2019-10-16 13:33:15',
#   'modifyDateTime': '2019-10-16 14:05:10',
#   'etc': None,
#   'ecgDataList': [{'ecgId': 785,
#     'organizationId': 8,
#     'measurementCode': 'SN191016MC100_P001',
#     'key': None,
#     'md5sum': 'c19798ba68c01431ada4735bf7f2458',
#     'sequenceNumber': 1,
#     'sampling': 256,
#     'gain': 100.0,
#     'endian': 1,
#     'deviceKind': 2,
#     'gmtCode': 'GMT+0900',
#     'startDateTime': '2019-10-16 12:48:53',
#     'endDateTime': '2019-10-16 13:33:15',
#     'uploadDateTime': '2019-10-16 13:33:22',
#     'modifyDateTime': None,
#     'fileSize': 1362944,
#     'ECGUrl': 'http://13.125.86.65:8080/mobiCARE/cardio/Measurement/DownloadECGFile/SN191016MC100_P001:785',
#     'filename': 'SN191016MC100_P001_01_20191016_133322.ecg'}],
#   'analysisOutputFileList': [{'analysisOutputFileId': 18922,
#     'organizationId': 8,
#     'measurementCode': 'SN191016MC100_P001',
#     'fileKey': None,
#     'md5sum': '40478b5f1e766f44d0ef9a1f83c7f7fd',
#     'fileType': 7,
#     'reanalyzing': 0,
#     'uploadDateTime': '2019-10-16 13:33:54',
#     'analysisUrl': 'http://13.125.86.65:8080/mobiCARE/cardio/Analysis/DownloadAnalysisOutputFile/SN191016MC100_P001:18922',
#     'filename': 'hbclass.txt'}],
#   'storePath': '/home/nsc/seers/cardio/database/mc100/SN191016MC100_P001'},
#  {'measurementId': 110,
#   'measurementCode': 'NSTest',
#   'registerUserId': 21,
#   'reviewerUserId': 21,
#   'deviceCode': '29410',
#   'organizationId': 8,
#   'patientCode': 'SEERSWESLEY',
#   'diseaseCode': None,
#   'firstName': 'Wesley',
#   'lastName': 'Kwon',
#   'gender': 1,
#   'birthday': '1983-03-13',
#   'height': 180.0,
#   'weight': 68.0,
#   'phoneNumber': None,
#   'measurementStatus': 6,
#   'shard': '2019',
#   'part': 29,
#   'reanalyzing': 0,
#   'deviceKind': 3,
#   'duration': 0,
#   'elapsedTime': 15593,
#   'gmtCode': 'GMT+0900',
#   'timezone': None,
#   'countryCode': None,
#   'dateTime': '2019-08-30 14:19:36',
#   'startDateTime': '2019-08-30 14:25:05',
#   'endDateTime': '2019-08-30 18:44:58',
#   'modifyDateTime': '2019-09-20 10:21:07',
#   'etc': 'Wesley Riding Check',
#   'ecgDataList': [{'ecgId': 203,
#     'organizationId': 8,
#     'measurementCode': 'NSTest',
#     'key': None,
#     'md5sum': 'd9e7c1468fdf71aa162b585f28ed84',
#     'sequenceNumber': 1,
#     'sampling': 256,
#     'gain': 100.0,
#     'endian': 1,
#     'deviceKind': 2,
#     'gmtCode': 'GMT+0900',
#     'startDateTime': '2019-08-30 14:25:05',
#     'endDateTime': '2019-08-30 18:44:58',
#     'uploadDateTime': '2019-09-02 09:03:48',
#     'modifyDateTime': None,
#     'fileSize': 7984384,
#     'ECGUrl': 'http://13.125.86.65:8080/mobiCARE/cardio/Measurement/DownloadECGFile/NSTest:203',
#     'filename': 'NSTest_01_20190830_142505.ecg'}],
#   'analysisOutputFileList': [{'analysisOutputFileId': 5474,
#     'organizationId': 8,
#     'measurementCode': 'NSTest',
#     'fileKey': None,
#     'md5sum': '2b59dc42c6c9a1072c9817f372398a0',
#     'fileType': 7,
#     'reanalyzing': 0,
#     'uploadDateTime': '2019-09-20 10:20:19',
#     'analysisUrl': 'http://13.125.86.65:8080/mobiCARE/cardio/Analysis/DownloadAnalysisOutputFile/NSTest:5474',
#     'filename': 'hbclass.txt'}],
#   'storePath': '/home/nsc/seers/cardio/database/mc100/NSTest'}]

# %%
# load MC100 review data

"""
measurementStatus
0x00 : NONE
0x01 : RECODING_START
0x02 : RECODING_END
0x03 : UPLOAD_COMPLETE
0x04 : ANALYZING
0x05 : READY
0x06 : REVIEWING
0x07 : COMPLETED
0x0A : REPORT RELEASE
0x0B : RE ANALYZING
0x0F : ERROR
"""
mc100 = MC100('/home/nsc/seers/cardio/database/mc100')
DOWNLOAD_PATH = mc100.DOWNLOAD_PATH
print ('Load Path : ', DOWNLOAD_PATH)

# get list review load
#mc100.get_list([0x07, 0x0A])
mc100.get_list([0x06, 0x07, 0x0A]) # for test

# create alarm annotation file
for idx, measurement in enumerate(mc100.list_measurement):       
    df_mc100_measurement_index = df_mc100.loc[df_mc100['measurementId'] == measurement['measurementId']].index
    print ('df_mc100 measurement index : ', df_mc100_measurement_index)
    
    if df_mc100_measurement_index.size is 0:
        print ('skip : not stored measurement - ', measurement['measurementCode'])
        continue

    print ('df_mc100 measurement status : ', df_mc100['measurementStatus'][df_mc100_measurement_index[0]])
    if df_mc100['measurementStatus'][df_mc100_measurement_index[0]] == 0x07:
        print ('skip : aleady stored review')
        continue
        
    # get review
    print ('get review - ', measurement['measurementCode'])
    mc100.get_review([measurement])

    if 'analysisBeatClassifySimpleList' not in measurement.keys():
        continue
   
    if measurement['analysisBeatClassifySimpleList'] is None:        
        continue
        
    record_name = measurement['measurementCode']
    print ('create alarm annoation - ', record_name)
    
    path = os.path.join(DOWNLOAD_PATH, record_name)
    fs = measurement['ecgDataList'][0]['sampling']
    sample = np.array([], dtype=int)  
    chan = np.array([], dtype=int)  
    symbol = []
    aux_note = []
    
    for analysis_beat in measurement['analysisBeatClassifySimpleList']:
        if analysis_beat['beatClass'] in ['VT']:
            sample = np.append(sample, analysis_beat['seconds'] * fs)
            symbol.append('"')
            aux_note.append('*** V-TACH ')
            chan = np.append(chan, 1) # true : 1, false = 3
        if analysis_beat['beatClass'] in ['VFL']:
            sample = np.append(sample, analysis_beat['seconds'] * fs)
            symbol.append('"')
            aux_note.append('*** V-FIB/TACH ')
            chan = np.append(chan, 1) # true : 1, false = 3
    
    sample = sample.astype('i')
    if len(sample) > 0:
        ann_alarm = wfdb.Annotation(record_name=record_name, extension='alM',
                                      sample=sample, symbol=symbol, aux_note=aux_note, 
                                      chan=chan, fs=fs)
        ann_alarm.wrann(write_fs=True, write_dir=path)
        # display(ann_alarm.__dict__)
    
    df_mc100['measurementStatus'][df_mc100_measurement_index[0]] = 0x07

if len(df_mc100) is not 0:
    df_mc100.to_csv(MC100_CSV, index = False, mode='w')
# Out:
# WAN ip : 14.40.50.110
# LAN ip : 127.0.1.1
# Login - POST request http://13.125.86.65:8080/mobiCARE/cardio/Account/Login
# True 200
# organization_id 8 token 1571663590291S0643S30
# Load Path :  /home/nsc/seers/cardio/database/mc100
# get list measure - POST request http://13.125.86.65:8080/mobiCARE/cardio/Measurement/SelectPatientMeasurementInfoByReviewer
# True 200
# count measurement 10
# get list ecg SN191021MC100_P012 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Measurement/SelectECGData
# True 200
# {"result":true,"extra":null,"systemTime":1571663590,"error":0,"message":null,"ecgDataList":null}
#
# get list ecg SN191018MC100_P009 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Measurement/SelectECGData
# True 200
# {"result":true,"extra":null,"systemTime":1571663590,"error":0,"message":null,"ecgDataList":null}
#
# get list ecg SN191018MC100_P007 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Measurement/SelectECGData
# True 200
# count ecg list 1
# {"result":true,"extra":null,"systemTime":1571663590,"error":0,"message":null,"ecgDataList":[{"ecgId":823,"organizationId":8,"measurementCode":"SN191018MC100_P007","key":null,"md5sum":"15f4d2f6b7304fddaa496619b835cd57","sequenceNumber":1,"sampling":256,"gain":100.0,"endian":1,"deviceKind":2,"gmtCode":"GMT+0900","startDateTime":"2019-10-18 13:30:40","endDateTime":"2019-10-18 14:01:39","uploadDateTime":"2019-10-18 14:01:44","modifyDateTime":null,"fileSize":952064}]}
#
# get list ecg SN191018MC100_P006 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Measurement/SelectECGData
# True 200
# count ecg list 1
# {"result":true,"extra":null,"systemTime":1571663590,"error":0,"message":null,"ecgDataList":[{"ecgId":822,"organizationId":8,"measurementCode":"SN191018MC100_P006","key":null,"md5sum":"659a9eddf796aebaf924ee668f5347","sequenceNumber":1,"sampling":256,"gain":100.0,"endian":1,"deviceKind":2,"gmtCode":"GMT+0900","startDateTime":"2019-10-18 12:57:36","endDateTime":"2019-10-18 13:28:11","uploadDateTime":"2019-10-18 13:28:16","modifyDateTime":null,"fileSize":939520}]}
#
# get list ecg SN191016MC100_P005 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Measurement/SelectECGData
# True 200
# count ecg list 1
# {"result":true,"extra":null,"systemTime":1571663590,"error":0,"message":null,"ecgDataList":[{"ecgId":797,"organizationId":8,"measurementCode":"SN191016MC100_P005","key":null,"md5sum":"fae212913292c4f518448412c61992a7","sequenceNumber":1,"sampling":256,"gain":100.0,"endian":1,"deviceKind":2,"gmtCode":"GMT+0900","startDateTime":"2019-10-16 16:24:04","endDateTime":"2019-10-16 16:55:15","uploadDateTime":"2019-10-16 16:55:21","modifyDateTime":null,"fileSize":958464}]}
#
# get list ecg SN191016MC100_P004 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Measurement/SelectECGData
# True 200
# count ecg list 1
# {"result":true,"extra":null,"systemTime":1571663590,"error":0,"message":null,"ecgDataList":[{"ecgId":796,"organizationId":8,"measurementCode":"SN191016MC100_P004","key":null,"md5sum":"bc9c62e9e67797e73783dc8f1c62de4","sequenceNumber":1,"sampling":256,"gain":100.0,"endian":1,"deviceKind":2,"gmtCode":"GMT+0900","startDateTime":"2019-10-16 15:47:10","endDateTime":"2019-10-16 16:20:38","uploadDateTime":"2019-10-16 16:20:49","modifyDateTime":null,"fileSize":1028608}]}
#
# get list ecg SN191016MC100_P003 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Measurement/SelectECGData
# True 200
# count ecg list 1
# {"result":true,"extra":null,"systemTime":1571663590,"error":0,"message":null,"ecgDataList":[{"ecgId":795,"organizationId":8,"measurementCode":"SN191016MC100_P003","key":null,"md5sum":"fb8e5f8f4c331917873bf2f5e6a67430","sequenceNumber":1,"sampling":256,"gain":100.0,"endian":1,"deviceKind":2,"gmtCode":"GMT+0900","startDateTime":"2019-10-16 15:01:22","endDateTime":"2019-10-16 15:32:07","uploadDateTime":"2019-10-16 15:32:12","modifyDateTime":null,"fileSize":944640}]}
#
# get list ecg SN191016MC100_P002 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Measurement/SelectECGData
# True 200
# count ecg list 1
# {"result":true,"extra":null,"systemTime":1571663590,"error":0,"message":null,"ecgDataList":[{"ecgId":786,"organizationId":8,"measurementCode":"SN191016MC100_P002","key":null,"md5sum":"7b4469d884b437e75c71364fadfe7b7","sequenceNumber":1,"sampling":256,"gain":100.0,"endian":1,"deviceKind":2,"gmtCode":"GMT+0900","startDateTime":"2019-10-16 13:55:39","endDateTime":"2019-10-16 14:26:26","uploadDateTime":"2019-10-16 14:26:33","modifyDateTime":null,"fileSize":946176}]}
#
# get list ecg SN191016MC100_P001 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Measurement/SelectECGData
# True 200
# count ecg list 1
# {"result":true,"extra":null,"systemTime":1571663590,"error":0,"message":null,"ecgDataList":[{"ecgId":785,"organizationId":8,"measurementCode":"SN191016MC100_P001","key":null,"md5sum":"c19798ba68c01431ada4735bf7f2458","sequenceNumber":1,"sampling":256,"gain":100.0,"endian":1,"deviceKind":2,"gmtCode":"GMT+0900","startDateTime":"2019-10-16 12:48:53","endDateTime":"2019-10-16 13:33:15","uploadDateTime":"2019-10-16 13:33:22","modifyDateTime":null,"fileSize":1362944}]}
#
# get list ecg NSTest - POST request http://13.125.86.65:8080/mobiCARE/cardio/Measurement/SelectECGData
# True 200
# count ecg list 1
# {"result":true,"extra":null,"systemTime":1571663590,"error":0,"message":null,"ecgDataList":[{"ecgId":203,"organizationId":8,"measurementCode":"NSTest","key":null,"md5sum":"d9e7c1468fdf71aa162b585f28ed84","sequenceNumber":1,"sampling":256,"gain":100.0,"endian":1,"deviceKind":2,"gmtCode":"GMT+0900","startDateTime":"2019-08-30 14:25:05","endDateTime":"2019-08-30 18:44:58","uploadDateTime":"2019-09-02 09:03:48","modifyDateTime":null,"fileSize":7984384}]}
#
# get list annotation SN191021MC100_P012 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Analysis/SelectAnalysisOutputAnnotationFile
# True 200
# {"result":true,"extra":null,"systemTime":1571663590,"error":0,"message":null,"analysisOutputFileList":null}
#
# get list annotation SN191018MC100_P009 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Analysis/SelectAnalysisOutputAnnotationFile
# True 200
# {"result":true,"extra":null,"systemTime":1571663590,"error":0,"message":null,"analysisOutputFileList":null}
#
# get list annotation SN191018MC100_P007 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Analysis/SelectAnalysisOutputAnnotationFile
# True 200
# count annotation list 1
# {"result":true,"extra":null,"systemTime":1571663590,"error":0,"message":null,"analysisOutputFileList":[{"analysisOutputFileId":20374,"organizationId":8,"measurementCode":"SN191018MC100_P007","fileKey":null,"md5sum":"58553ae5f73499468a65e7b8e20226","fileType":7,"reanalyzing":0,"uploadDateTime":"2019-10-18 14:04:14"}]}
#
# get list annotation SN191018MC100_P006 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Analysis/SelectAnalysisOutputAnnotationFile
# True 200
# count annotation list 1
# {"result":true,"extra":null,"systemTime":1571663590,"error":0,"message":null,"analysisOutputFileList":[{"analysisOutputFileId":19758,"organizationId":8,"measurementCode":"SN191018MC100_P006","fileKey":null,"md5sum":"a52c59528c29287bc8932e88d92630","fileType":7,"reanalyzing":0,"uploadDateTime":"2019-10-18 13:28:34"}]}
#
# get list annotation SN191016MC100_P005 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Analysis/SelectAnalysisOutputAnnotationFile
# True 200
# count annotation list 1
# {"result":true,"extra":null,"systemTime":1571663590,"error":0,"message":null,"analysisOutputFileList":[{"analysisOutputFileId":19177,"organizationId":8,"measurementCode":"SN191016MC100_P005","fileKey":null,"md5sum":"8aae22b0dc9671ffb0d810ed24de624f","fileType":7,"reanalyzing":0,"uploadDateTime":"2019-10-16 16:55:52"}]}
#
# get list annotation SN191016MC100_P004 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Analysis/SelectAnalysisOutputAnnotationFile
# True 200
# count annotation list 1
# {"result":true,"extra":null,"systemTime":1571663590,"error":0,"message":null,"analysisOutputFileList":[{"analysisOutputFileId":19163,"organizationId":8,"measurementCode":"SN191016MC100_P004","fileKey":null,"md5sum":"4ad644c0f53395bffab7d94fb586b2e1","fileType":7,"reanalyzing":0,"uploadDateTime":"2019-10-16 16:21:12"}]}
#
# get list annotation SN191016MC100_P003 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Analysis/SelectAnalysisOutputAnnotationFile
# True 200
# count annotation list 1
# {"result":true,"extra":null,"systemTime":1571663590,"error":0,"message":null,"analysisOutputFileList":[{"analysisOutputFileId":19128,"organizationId":8,"measurementCode":"SN191016MC100_P003","fileKey":null,"md5sum":"997abfa65cf827935aaaf702484ad3","fileType":7,"reanalyzing":0,"uploadDateTime":"2019-10-16 15:32:33"}]}
#
# get list annotation SN191016MC100_P002 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Analysis/SelectAnalysisOutputAnnotationFile
# True 200
# count annotation list 1
# {"result":true,"extra":null,"systemTime":1571663590,"error":0,"message":null,"analysisOutputFileList":[{"analysisOutputFileId":18937,"organizationId":8,"measurementCode":"SN191016MC100_P002","fileKey":null,"md5sum":"1bdd83925623118cc2d383366eeef53d","fileType":7,"reanalyzing":0,"uploadDateTime":"2019-10-16 14:27:12"}]}
#
# get list annotation SN191016MC100_P001 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Analysis/SelectAnalysisOutputAnnotationFile
# True 200
# count annotation list 1
# {"result":true,"extra":null,"systemTime":1571663590,"error":0,"message":null,"analysisOutputFileList":[{"analysisOutputFileId":18922,"organizationId":8,"measurementCode":"SN191016MC100_P001","fileKey":null,"md5sum":"40478b5f1e766f44d0ef9a1f83c7f7fd","fileType":7,"reanalyzing":0,"uploadDateTime":"2019-10-16 13:33:54"}]}
#
# get list annotation NSTest - POST request http://13.125.86.65:8080/mobiCARE/cardio/Analysis/SelectAnalysisOutputAnnotationFile
# True 200
# count annotation list 1
# {"result":true,"extra":null,"systemTime":1571663590,"error":0,"message":null,"analysisOutputFileList":[{"analysisOutputFileId":5474,"organizationId":8,"measurementCode":"NSTest","fileKey":null,"md5sum":"2b59dc42c6c9a1072c9817f372398a0","fileType":7,"reanalyzing":0,"uploadDateTime":"2019-09-20 10:20:19"}]}
#
# df_mc100 measurement index :  Int64Index([], dtype='int64')
# skip : not stored measurement -  SN191021MC100_P012
# df_mc100 measurement index :  Int64Index([], dtype='int64')
# skip : not stored measurement -  SN191018MC100_P009
# df_mc100 measurement index :  Int64Index([0], dtype='int64')
# df_mc100 measurement status :  5
# get review -  SN191018MC100_P007
# get review SN191018MC100_P007 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Analysis/SelectAnalysisBeatClassify
# True 200
#
# create alarm annoation -  SN191018MC100_P007
# df_mc100 measurement index :  Int64Index([1], dtype='int64')
# df_mc100 measurement status :  5
# get review -  SN191018MC100_P006
# get review SN191018MC100_P006 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Analysis/SelectAnalysisBeatClassify
# /home/nsc/anaconda3/envs/py36_tfgpu/lib/python3.6/site-packages/ipykernel_launcher.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# True 200
#
# create alarm annoation -  SN191018MC100_P006
# df_mc100 measurement index :  Int64Index([2], dtype='int64')
# df_mc100 measurement status :  5
# get review -  SN191016MC100_P005
# get review SN191016MC100_P005 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Analysis/SelectAnalysisBeatClassify
# True 200
#
# create alarm annoation -  SN191016MC100_P005
# df_mc100 measurement index :  Int64Index([3], dtype='int64')
# df_mc100 measurement status :  5
# get review -  SN191016MC100_P004
# get review SN191016MC100_P004 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Analysis/SelectAnalysisBeatClassify
# True 200
#
# create alarm annoation -  SN191016MC100_P004
# df_mc100 measurement index :  Int64Index([4], dtype='int64')
# df_mc100 measurement status :  5
# get review -  SN191016MC100_P003
# get review SN191016MC100_P003 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Analysis/SelectAnalysisBeatClassify
# True 200
#
# create alarm annoation -  SN191016MC100_P003
# df_mc100 measurement index :  Int64Index([5], dtype='int64')
# df_mc100 measurement status :  5
# get review -  SN191016MC100_P002
# get review SN191016MC100_P002 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Analysis/SelectAnalysisBeatClassify
# True 200
#
# create alarm annoation -  SN191016MC100_P002
# df_mc100 measurement index :  Int64Index([6], dtype='int64')
# df_mc100 measurement status :  5
# get review -  SN191016MC100_P001
# get review SN191016MC100_P001 - POST request http://13.125.86.65:8080/mobiCARE/cardio/Analysis/SelectAnalysisBeatClassify
# True 200
#
# create alarm annoation -  SN191016MC100_P001
# df_mc100 measurement index :  Int64Index([7], dtype='int64')
# df_mc100 measurement status :  5
# get review -  NSTest
# get review NSTest - POST request http://13.125.86.65:8080/mobiCARE/cardio/Analysis/SelectAnalysisBeatClassify
# True 200
#
# create alarm annoation -  NSTest

# %%
# MC100 data view

count = len(mc100.list_measurement)
for idx, measurement in enumerate(mc100.list_measurement):
    if measurement['ecgDataList'] is None:
        continue
    
    record_name = measurement['measurementCode']
    fs = measurement['ecgDataList'][0]['sampling']
        
    path = os.path.join(DOWNLOAD_PATH, record_name)
    #start = fs*12
    start = 0
    #end = fs*40
    end = int(measurement['ecgDataList'][0]['fileSize'] / 2) # the end
    annotation = wfdb.rdann(os.path.join(path, record_name), 'atr',
                            sampfrom = start, sampto = end,)
    annotation.sample = annotation.sample - start
    record = wfdb.rdrecord(os.path.join(path, record_name), 
                           sampfrom = start, sampto = end,)
    str_title = ("%d/%d - %s - %s - %s" % 
                      (idx+1, count,
                       record.record_name,
                       'MC100',
                       'beat annotation')
                    )
    print(str_title)
    wfdb.plot_wfdb(record=record, annotation=annotation,
                   time_units='seconds', title=str_title, 
                   plot_sym=True, figsize=(10,3))
    
    
    #start = fs*12
    start = 0
    #end = fs*40
    end = int(measurement['ecgDataList'][0]['fileSize'] / 2) # the end
    alarm = wfdb.rdann(os.path.join(path, record_name), 'alM',
                            sampfrom = start, sampto = end,)
    alarm.sample = alarm.sample - start
    record = wfdb.rdrecord(os.path.join(path, record_name), 
                           sampfrom = start, sampto = end,)
    str_title = ("%d/%d - %s - %s - %s" % 
                      (idx+1, count,
                       record.record_name,
                       'MC100',
                       'Alarm Viewer')
                    )
    print(str_title)
    wfdb.plot_wfdb(record=record, annotation=alarm,
                   time_units='seconds', title=str_title, 
                   figsize=(10,4))
    display(record.__dict__)
# Out:
# 3/10 - SN191018MC100_P007 - MC100 - beat annotation
# 3/10 - SN191018MC100_P007 - MC100 - Alarm Viewer
# {'record_name': 'SN191018MC100_P007',
#  'n_sig': 1,
#  'fs': 256,
#  'counter_freq': None,
#  'base_counter': None,
#  'sig_len': 476032,
#  'base_time': datetime.time(13, 30, 40),
#  'base_date': datetime.date(2019, 10, 18),
#  'comments': [],
#  'sig_name': ['II'],
#  'p_signal': array([[20.65],
#         [20.64],
#         [20.65],
#         ...,
#         [20.63],
#         [20.63],
#         [20.65]]),
#  'd_signal': None,
#  'e_p_signal': None,
#  'e_d_signal': None,
#  'file_name': ['SN191018MC100_P007_01_20191018_140144.ecg'],
#  'fmt': ['16'],
#  'samps_per_frame': [1],
#  'skew': [None],
#  'byte_offset': [None],
#  'adc_gain': [100.0],
#  'baseline': [0],
#  'units': ['mV'],
#  'adc_res': [16],
#  'adc_zero': [0],
#  'init_value': [0],
#  'checksum': [0],
#  'block_size': [0],
#  'base_datetime': datetime.datetime(2019, 10, 18, 13, 30, 40)}
# 4/10 - SN191018MC100_P006 - MC100 - beat annotation
# 4/10 - SN191018MC100_P006 - MC100 - Alarm Viewer
# {'record_name': 'SN191018MC100_P006',
#  'n_sig': 1,
#  'fs': 256,
#  'counter_freq': None,
#  'base_counter': None,
#  'sig_len': 469760,
#  'base_time': datetime.time(12, 57, 36),
#  'base_date': datetime.date(2019, 10, 18),
#  'comments': [],
#  'sig_name': ['II'],
#  'p_signal': array([[ 0.  ],
#         [ 0.  ],
#         [ 0.  ],
#         ...,
#         [20.64],
#         [20.65],
#         [20.66]]),
#  'd_signal': None,
#  'e_p_signal': None,
#  'e_d_signal': None,
#  'file_name': ['SN191018MC100_P006_01_20191018_132816.ecg'],
#  'fmt': ['16'],
#  'samps_per_frame': [1],
#  'skew': [None],
#  'byte_offset': [None],
#  'adc_gain': [100.0],
#  'baseline': [0],
#  'units': ['mV'],
#  'adc_res': [16],
#  'adc_zero': [0],
#  'init_value': [0],
#  'checksum': [0],
#  'block_size': [0],
#  'base_datetime': datetime.datetime(2019, 10, 18, 12, 57, 36)}
# 5/10 - SN191016MC100_P005 - MC100 - beat annotation
# 5/10 - SN191016MC100_P005 - MC100 - Alarm Viewer
# {'record_name': 'SN191016MC100_P005',
#  'n_sig': 1,
#  'fs': 256,
#  'counter_freq': None,
#  'base_counter': None,
#  'sig_len': 479232,
#  'base_time': datetime.time(16, 24, 4),
#  'base_date': datetime.date(2019, 10, 16),
#  'comments': [],
#  'sig_name': ['II'],
#  'p_signal': array([[20.62],
#         [20.62],
#         [20.62],
#         ...,
#         [20.64],
#         [20.63],
#         [20.62]]),
#  'd_signal': None,
#  'e_p_signal': None,
#  'e_d_signal': None,
#  'file_name': ['SN191016MC100_P005_01_20191016_165521.ecg'],
#  'fmt': ['16'],
#  'samps_per_frame': [1],
#  'skew': [None],
#  'byte_offset': [None],
#  'adc_gain': [100.0],
#  'baseline': [0],
#  'units': ['mV'],
#  'adc_res': [16],
#  'adc_zero': [0],
#  'init_value': [0],
#  'checksum': [0],
#  'block_size': [0],
#  'base_datetime': datetime.datetime(2019, 10, 16, 16, 24, 4)}
# 6/10 - SN191016MC100_P004 - MC100 - beat annotation
# 6/10 - SN191016MC100_P004 - MC100 - Alarm Viewer
# {'record_name': 'SN191016MC100_P004',
#  'n_sig': 1,
#  'fs': 256,
#  'counter_freq': None,
#  'base_counter': None,
#  'sig_len': 514304,
#  'base_time': datetime.time(15, 47, 10),
#  'base_date': datetime.date(2019, 10, 16),
#  'comments': [],
#  'sig_name': ['II'],
#  'p_signal': array([[20.62],
#         [20.62],
#         [20.61],
#         ...,
#         [20.64],
#         [20.62],
#         [20.61]]),
#  'd_signal': None,
#  'e_p_signal': None,
#  'e_d_signal': None,
#  'file_name': ['SN191016MC100_P004_01_20191016_162049.ecg'],
#  'fmt': ['16'],
#  'samps_per_frame': [1],
#  'skew': [None],
#  'byte_offset': [None],
#  'adc_gain': [100.0],
#  'baseline': [0],
#  'units': ['mV'],
#  'adc_res': [16],
#  'adc_zero': [0],
#  'init_value': [0],
#  'checksum': [0],
#  'block_size': [0],
#  'base_datetime': datetime.datetime(2019, 10, 16, 15, 47, 10)}
# 7/10 - SN191016MC100_P003 - MC100 - beat annotation
# 7/10 - SN191016MC100_P003 - MC100 - Alarm Viewer
# {'record_name': 'SN191016MC100_P003',
#  'n_sig': 1,
#  'fs': 256,
#  'counter_freq': None,
#  'base_counter': None,
#  'sig_len': 472320,
#  'base_time': datetime.time(15, 1, 22),
#  'base_date': datetime.date(2019, 10, 16),
#  'comments': [],
#  'sig_name': ['II'],
#  'p_signal': array([[ 0.  ],
#         [ 0.  ],
#         [ 0.  ],
#         ...,
#         [20.61],
#         [20.6 ],
#         [20.6 ]]),
#  'd_signal': None,
#  'e_p_signal': None,
#  'e_d_signal': None,
#  'file_name': ['SN191016MC100_P003_01_20191016_153212.ecg'],
#  'fmt': ['16'],
#  'samps_per_frame': [1],
#  'skew': [None],
#  'byte_offset': [None],
#  'adc_gain': [100.0],
#  'baseline': [0],
#  'units': ['mV'],
#  'adc_res': [16],
#  'adc_zero': [0],
#  'init_value': [0],
#  'checksum': [0],
#  'block_size': [0],
#  'base_datetime': datetime.datetime(2019, 10, 16, 15, 1, 22)}
# 8/10 - SN191016MC100_P002 - MC100 - beat annotation
# 8/10 - SN191016MC100_P002 - MC100 - Alarm Viewer
# {'record_name': 'SN191016MC100_P002',
#  'n_sig': 1,
#  'fs': 256,
#  'counter_freq': None,
#  'base_counter': None,
#  'sig_len': 473088,
#  'base_time': datetime.time(13, 55, 39),
#  'base_date': datetime.date(2019, 10, 16),
#  'comments': [],
#  'sig_name': ['II'],
#  'p_signal': array([[21.15],
#         [21.  ],
#         [21.06],
#         ...,
#         [20.61],
#         [20.62],
#         [20.64]]),
#  'd_signal': None,
#  'e_p_signal': None,
#  'e_d_signal': None,
#  'file_name': ['SN191016MC100_P002_01_20191016_142633.ecg'],
#  'fmt': ['16'],
#  'samps_per_frame': [1],
#  'skew': [None],
#  'byte_offset': [None],
#  'adc_gain': [100.0],
#  'baseline': [0],
#  'units': ['mV'],
#  'adc_res': [16],
#  'adc_zero': [0],
#  'init_value': [0],
#  'checksum': [0],
#  'block_size': [0],
#  'base_datetime': datetime.datetime(2019, 10, 16, 13, 55, 39)}
# 9/10 - SN191016MC100_P001 - MC100 - beat annotation
# 9/10 - SN191016MC100_P001 - MC100 - Alarm Viewer
# {'record_name': 'SN191016MC100_P001',
#  'n_sig': 1,
#  'fs': 256,
#  'counter_freq': None,
#  'base_counter': None,
#  'sig_len': 681472,
#  'base_time': datetime.time(12, 48, 53),
#  'base_date': datetime.date(2019, 10, 16),
#  'comments': [],
#  'sig_name': ['II'],
#  'p_signal': array([[20.59],
#         [20.6 ],
#         [20.59],
#         ...,
#         [20.63],
#         [20.62],
#         [20.64]]),
#  'd_signal': None,
#  'e_p_signal': None,
#  'e_d_signal': None,
#  'file_name': ['SN191016MC100_P001_01_20191016_133322.ecg'],
#  'fmt': ['16'],
#  'samps_per_frame': [1],
#  'skew': [None],
#  'byte_offset': [None],
#  'adc_gain': [100.0],
#  'baseline': [0],
#  'units': ['mV'],
#  'adc_res': [16],
#  'adc_zero': [0],
#  'init_value': [0],
#  'checksum': [0],
#  'block_size': [0],
#  'base_datetime': datetime.datetime(2019, 10, 16, 12, 48, 53)}
# 10/10 - NSTest - MC100 - beat annotation
# 10/10 - NSTest - MC100 - Alarm Viewer
# {'record_name': 'NSTest',
#  'n_sig': 1,
#  'fs': 256,
#  'counter_freq': None,
#  'base_counter': None,
#  'sig_len': 3992192,
#  'base_time': datetime.time(14, 25, 5),
#  'base_date': datetime.date(2019, 8, 30),
#  'comments': [],
#  'sig_name': ['II'],
#  'p_signal': array([[29.53],
#         [27.77],
#         [25.99],
#         ...,
#         [19.02],
#         [19.03],
#         [19.03]]),
#  'd_signal': None,
#  'e_p_signal': None,
#  'e_d_signal': None,
#  'file_name': ['NSTest_01_20190830_142505.ecg'],
#  'fmt': ['16'],
#  'samps_per_frame': [1],
#  'skew': [None],
#  'byte_offset': [None],
#  'adc_gain': [100.0],
#  'baseline': [0],
#  'units': ['mV'],
#  'adc_res': [16],
#  'adc_zero': [0],
#  'init_value': [0],
#  'checksum': [0],
#  'block_size': [0],
#  'base_datetime': datetime.datetime(2019, 8, 30, 14, 25, 5)}
